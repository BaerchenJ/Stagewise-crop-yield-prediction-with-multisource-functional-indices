# %%
import ast
import os
import csv
from datetime import datetime
import fiona
import requests as r
import numpy as np
import pandas as pd
import geopandas as gp
from skimage import io
import matplotlib.pyplot as plt
from osgeo import gdal
import rasterio as rio
import json
from rasterio.mask import mask
from rasterio.enums import Resampling
from rasterio.shutil import copy
from pathlib import Path
import pickle
import pyproj
from pyproj import Proj
from shapely.ops import transform
import xarray as xr
import geoviews as gv
from cartopy import crs
import hvplot.xarray
import holoviews as hv
gv.extension('bokeh', 'matplotlib')

# Set Up Working Environment
inDir = os.getcwd()
os.chdir(inDir)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# ...

# %%
mydir = '.../Illisoy/CPC-SOY/cpc2019/condition'  ## firstly raw phenology gridded data should be downloaded

sClist = []

sClist += [each for each in os.listdir(mydir) if each.endswith('.tif')]

sClist

# %%
directory='.../Illisoy/Illinois_shp/county_shape_files/ToJSON'

CSlist = os.listdir(directory)

CSlist

# %%
### before run the loop below, reprojection

from rasterio.warp import calculate_default_transform, reproject, Resampling

for filename in sClist:
    
    field = gp.read_file('.../Illisoy/Illinois_shp/county_shape_files/ToJSON/ADAMS.json')
    dst_crs = field.crs
    mydir = '.../Illisoy/PHENOLOGY/cpc2019/condition'
    with rio.open(os.path.join(mydir, filename)) as src:
        transform, width, height = calculate_default_transform(
           src.crs, dst_crs, src.width, src.height, *src.bounds)
        kwargs = src.meta.copy()
        kwargs.update({
            'crs': dst_crs,
            'transform': transform,
            'width': width,
            'height': height
        })

        with rio.open('.../Illisoy/PHENOLOGY/2019Con/' + filename, 'w', **kwargs) as dst:
             for i in range(1, src.count + 1):
                reproject(
                   source=rio.band(src, i),
                   destination=rio.band(dst, i),
                   src_transform=src.transform,
                   src_crs=src.crs,
                   dst_transform=transform,
                   dst_crs=dst_crs,
                   resampling=Resampling.nearest)

# %%
for countyname in CSlist:

    directory = '.../Illisoy/Illinois_shp/county_shape_files/ToJSON'

    for filename in sClist:

        mydir = '.../Illisoy/PHENOLOGY/2019Con'

        try: 
            with fiona.open(os.path.join(directory, countyname), "r") as shapefile:
                shapes = [feature["geometry"] for feature in shapefile]

            with rio.open(os.path.join(mydir, filename)) as src:
                out_image, out_transform = rio.mask.mask(src, shapes, crop=True)
            out_meta = src.meta
 
            out_meta.update({"driver": "GTiff",
                             "height": out_image.shape[1],
                             "width": out_image.shape[2],
                             "transform": out_transform})

            dirname = '.../Illisoy/PHENOLOGY/2019Con/County'

            with rio.open(os.path.join(dirname, Path(os.path.join(directory, countyname)).stem + filename), "w", **out_meta) as dest:
                dest.write(out_image)

        except:
            print(f"{filename} does not provide the dates, move to the next file.")
            continue
# Out:
# SoyCond19w48.tif does not provide the dates, move to the next file.
# SoyCond19w48.tif does not provide the dates, move to the next file.
# SoyCond19w47.tif does not provide the dates, move to the next file.
# SoyCond19w21.tif does not provide the dates, move to the next file.
# SoyCond19w48.tif does not provide the dates, move to the next file.
# SoyCond19w46.tif does not provide the dates, move to the next file.
# SoyCond19w20.tif does not provide the dates, move to the next file.
# SoyCond19w45.tif does not provide the dates, move to the next file.
# SoyCond19w47.tif does not provide the dates, move to the next file.
# SoyCond19w19.tif does not provide the dates, move to the next file.
# SoyCond19w21.tif does not provide the dates, move to the next file.
# SoyCond19w48.tif does not provide the dates, move to the next file.
# SoyCond19w20.tif does not provide the dates, move to the next file.
# SoyCond19w47.tif does not provide the dates, move to the next file.
# ...

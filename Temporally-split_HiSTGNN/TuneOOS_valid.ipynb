# %%
import argparse
import time
import math
import csv
import pandas as pd
from util import *
from layer import *
from trainer import DoubleTrainer
from HierNet import HierarchicalNet
from datetime import datetime

# %%
def str_to_bool(value):
    if isinstance(value, bool):
        return value
    if value.lower() in {'false', 'f', '0', 'no', 'n'}:
        return False
    elif value.lower() in {'true', 't', '1', 'yes', 'y'}:
        return True
    raise ValueError(f'{value} is not a valid boolean value')

## --gcn_depth 2 --num_var 4 --var_nodes 4 --stat_nodes 96 --var_node_dim 10 --stat_node_dim 10 --seq_in_len 26 --seq_out_len 1 --batch_size 4 --tanhalpha 2

######################################### Illinois settings ###################################
parser = argparse.ArgumentParser()

parser.add_argument('--device',type=str,default='cpu',help='')
parser.add_argument('--dir',type=str,default='',help='data path')
parser.add_argument('--data_name',type=str,default='Illinois',help='dataset name')

parser.add_argument('--hier_true', type=str_to_bool, default=False, help='whether to use flat graph')
parser.add_argument('--DIL_true', type=str_to_bool, default=True, help='whether to use Dynamic Interaction learning')
parser.add_argument('--gcn_true', type=str_to_bool, default=True, help='whether to add graph convolution layer')
parser.add_argument('--gat_true', type=str_to_bool, default=False, help='whether to add graph attention layer')
parser.add_argument('--buildA_true', type=str_to_bool, default=True, help='whether to construct adaptive adjacency matrix')

parser.add_argument('--gcn_depth',type=int,default=2,help='graph convolution depth')
parser.add_argument('--num_var', type=int, default=4,help='var num during encoding phrase for ablation study') 
parser.add_argument('--var_nodes',type=int,default=4,help='number of nodes/indices')
parser.add_argument('--stat_nodes',type=int,default=96,help='number of nodes/locations')
parser.add_argument('--num_heads',type=int,default=4,help='number of multi-head for graph attention') 
parser.add_argument('--dropout',type=float,default=0.3,help='dropout rate')
parser.add_argument('--var_node_dim',type=int,default=20,help='dim of nodes') 
parser.add_argument('--stat_node_dim',type=int,default=20,help='dim of nodes') 
parser.add_argument('--dilation_exponential',type=int,default=1,help='dilation exponential')

parser.add_argument('--conv_channels',type=int,default=16,help='convolution channels') 
parser.add_argument('--residual_channels',type=int,default=16,help='residual channels') 
parser.add_argument('--skip_channels',type=int,default=32,help='skip channels') 
parser.add_argument('--end_channels',type=int,default=64,help='end channels') 

parser.add_argument('--in_dim',type=int,default=2,help='inputs dimension')  
parser.add_argument('--seq_in_len',type=int,default=26,help='input sequence length')
parser.add_argument('--seq_out_len',type=int,default=1,help='output sequence length') ### can be 1 or not

parser.add_argument('--layers',type=int,default=3,help='number of layers')
parser.add_argument('--batch_size',type=int,default=4,help='batch size')
parser.add_argument('--learning_rate',type=float,default=0.001,help='learning rate')
parser.add_argument('--propalpha',type=float,default=0.05,help='prop alpha')
parser.add_argument('--tanhalpha',type=float,default=1,help='adj alpha')
parser.add_argument('--weight_decay',type=float,default=0.0001,help='weight decay rate')
parser.add_argument('--clip',type=int,default=5,help='clip')

parser.add_argument('--step_size1',type=int,default=1,help='step_size')
parser.add_argument('--step_size2',type=int,default=100,help='step_size')

parser.add_argument('--epochs',type=int,default=20,help='num of train epoch')
parser.add_argument('--print_every',type=int,default=10,help='print information every n iteration')
parser.add_argument('--seed',type=int,default=101,help='random seed')
#parser.add_argument('--patient',type=int,default=10,help='early stop')

parser.add_argument('--expid',type=int,default=1,help='experiment id')
parser.add_argument('--runs',type=int,default=1,help='number of runs')

args, unknown = parser.parse_known_args()
torch.set_num_threads(3)

# %%
runid = 1
torch.manual_seed(args.seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(args.seed)

# load data
device = torch.device(args.device)
dir = args.dir

from helper import load_pkl  
from util import DataLoaderM 

def load_Illinois_dataset(dataset_dir, dictname, batch_size, device='cpu'):

    ori_data = load_pkl(dataset_dir, dictname)
    
    data = {}
    for category in ['train', 'val', 'test']:
        tmpilli = ori_data['x_' + category]
        num_year, num_sample, num_variables, num_column = tmpilli.shape  ## num_sample is the number of rows in one year (26*number of counties)

        ## reshape x_category
        allinlist =[]
        num_week = 26
        num_county = 96
        for eachyear in tmpilli:
            for eachweek in eachyear:
                for eachindex in eachweek:
                    allinlist.append(eachindex[3])       
        Yearlist = []
        for i in range(1, num_year +1):
            x = allinlist[(i-1)*num_sample*num_variables : i*num_sample*num_variables]
            Yearlist.append(x)
        Countylist = []
        for eachyear in Yearlist:    
            for i in range(1, num_county +1):
                x = eachyear[(i-1)*num_week*num_variables : i*num_week*num_variables]
                Countylist.append(x)
        Weeklist = []
        for ii in range(20, 45+1):
            for eachcounty in Countylist:
                x = eachcounty[(ii-20)*num_variables : (ii-20+1)*num_variables]
                Weeklist.append(x)
        Weeksequence = []
        for ii in range(1, num_year +1):
            for j in range(1, num_week +1):
                x = Weeklist[(ii-1)*num_county + (j-1)*num_year*num_county : (ii-1)*num_county + (j-1)*num_year*num_county + num_county]
                Weeksequence.append(x)
        Yearweeksequence = []
        for i in range(1, num_year + 1):
            Yearweeksequence.append(Weeksequence[(i-1)*num_week : i*num_week])
        x_array = np.array(Yearweeksequence)
        tmp = x_array
        num_years, num_weeks, num_counties, num_indices = tmp.shape
        tmp = np.expand_dims(tmp, axis=-1)
        tmp_list = [tmp]
        time_ind = [(i % 26) / 26 for i in range(num_weeks)]  # week in year
        time_ind = np.array(time_ind) # 26
        week_in_year = np.tile(time_ind, [num_years, 1, num_counties, num_indices, 1]).transpose((0, 4, 2, 3, 1))
        tmp_list.append(week_in_year)
        data['x_' + category] = np.concatenate(tmp_list, axis=-1)

        ## reshape y_category
        tmp_y = ori_data['y_' + category]
        allyieldlist = []
        for eachline in tmp_y:    
            allyieldlist.append(eachline[2])
        Yearyieldlist = []
        for ii in range(1, num_years +1):
            x = allyieldlist[(ii-1)*num_counties : ii*num_counties]
            Yearyieldlist.append(x)
        y_array = np.array(Yearyieldlist)
        data['y_' + category] = np.expand_dims(y_array, axis=-1) # [year, county, yield]

    data['train_loader'] = DataLoaderM(data['x_train'], data['y_train'], batch_size)
    data['val_loader'] = DataLoaderM(data['x_val'], data['y_val'], batch_size)
    data['test_loader'] = DataLoaderM(data['x_test'], data['y_test'], batch_size)

    return data
    
# Illinois
dataloader = load_Illinois_dataset(dataset_dir = args.dir, dictname = 'illi_data_sepanormal_temporal.dict', batch_size = args.batch_size, device=args.device)

if args.data_name == "Illinois":
   conv_k_size = (1, 4, 1)


model = HierarchicalNet(seq_length=args.seq_in_len, n_var=args.var_nodes, n_stat=args.stat_nodes, var_dim=args.var_node_dim,
                        stat_dim=args.stat_node_dim, device=args.device, tanhalpha=args.tanhalpha, conv_channels=args.conv_channels,
                        gcn_depth=args.gcn_depth, residual_channels=args.residual_channels, in_dim=args.in_dim,
                        dropout=args.dropout, end_channels=args.end_channels, out_dim=args.seq_out_len,
                        propalpha=args.propalpha, predefined_A=args.buildA_true, static_feat=None, dilation_exponential=args.dilation_exponential,
                        layers=args.layers, layer_norm_affline=True, skip_channels=args.skip_channels,
                        gcn_true=args.gcn_true, gat_true=args.gat_true, num_heads = args.num_heads, hier_true=args.hier_true, DIL_true=args.DIL_true, conv_k_size=conv_k_size)

print(args)
print('The receptive field size is', model.receptive_field)
nParams = sum([p.nelement() for p in model.parameters()])
print('Number of model parameters is', nParams)

engine = DoubleTrainer(model, args.learning_rate, args.weight_decay, args.clip, args.step_size1, args.seq_out_len, device=args.device)

print("start training...",flush=True)
# Out:
# illi_data_sepanormal_temporal.dict  is loaded from:
# Namespace(device='cpu', dir='', data_name='Illinois', hier_true=False, DIL_true=True, gcn_true=True, gat_true=False, buildA_true=True, gcn_depth=2, num_var=4, var_nodes=4, stat_nodes=96, num_heads=4, dropout=0.3, var_node_dim=20, stat_node_dim=20, dilation_exponential=1, conv_channels=16, residual_channels=16, skip_channels=32, end_channels=64, in_dim=2, seq_in_len=26, seq_out_len=1, layers=3, batch_size=4, learning_rate=0.001, propalpha=0.05, tanhalpha=1, weight_decay=0.0001, clip=5, step_size1=1, step_size2=100, epochs=20, print_every=10, seed=101, expid=1, runs=1)
# The receptive field size is 16
# Number of model parameters is 1780870
# start training...

# %%
## validation loss

his_train_loss = []
his_valid_loss =[]
his_valid_rmse = []
his_valid_pred = []
train_time = []
valid_time = []

for i in range(1,args.epochs+1):# epochs   
    
    train_loss = []
    train_mae = []
    train_mape = []
    train_rmse = []
    t1 = time.time()
    
    dataloader['train_loader'].shuffle() # shuffle train_loader data
    
    for iter, (x, y) in enumerate(dataloader['train_loader'].get_iterator()):
        trainx = torch.Tensor(x).to(device)
        trainx = trainx.transpose(1, 4)
        trainy = torch.Tensor(y).to(device)
        metrics = engine.train(trainx, trainy, iter, data_name=args.data_name)
        train_loss.append(metrics[0])
        train_mae.append(metrics[1])
        train_mape.append(metrics[2])
        train_rmse.append(metrics[3])
    
        if iter % args.print_every == 0 :
            log = 'Iter: {:03d}, Train Loss: {:.4f}, Train MAE: {:.4f}, Train MAPE: {:.4f}, Train RMSE: {:.4f}'
            print(log.format(iter, train_loss[-1], train_mae[-1], train_mape[-1], train_rmse[-1]),flush=True)
    
        t2 = time.time()
        train_time.append(t2-t1)
    
        # validation data
        valid_mae = []
        valid_mape = []
        valid_rmse = []
        valid_pred = []
    
        s1 = time.time()
        for iter, (x, y) in enumerate(dataloader['val_loader'].get_iterator()):
            validx = torch.Tensor(x).to(device)
            validx = validx.transpose(1, 4)
            validy = torch.Tensor(y).to(device)

            if i !=20 :
               metrics = engine.eval(validx, validy, data_name=args.data_name) # first reduce, then expand y:(batch, variables, time)
               valid_mae.append(metrics[0])
               valid_mape.append(metrics[1])
               valid_rmse.append(metrics[2])
            else:    
               metrics = engine.evalbest(validx, validy, data_name=args.data_name) # first reduce, then expand y:(batch, variables, time)
               valid_mae.append(metrics[0])
               valid_mape.append(metrics[1])
               valid_rmse.append(metrics[2])
               valid_pred.append(metrics[3])                    
            
        s2 = time.time()
        log = 'Epoch: {:03d}, Inference Time: {:.4f} secs'
        print(log.format(i,(s2-s1)))
        valid_time.append(s2-s1)
    
        mtrain_loss = np.mean(train_loss)
        mtrain_mape = np.mean(train_mape)
        mtrain_rmse = np.mean(train_rmse)
        his_train_loss.append(mtrain_loss)
    
        mvalid_loss = np.mean(valid_mae)
        mvalid_mape = np.mean(valid_mape)
        mvalid_rmse = np.mean(valid_rmse)
        his_valid_loss.append(mvalid_loss)
        his_valid_rmse.append(mvalid_rmse)
        his_valid_pred.append(valid_pred)
    
        log = 'Epoch: {:03d}, Train Loss: {:.4f}, Train MAPE: {:.4f}, Train RMSE: {:.4f}, Validation Loss: {:.4f}, ' \
              'Validation MAPE: {:.4f}, Validation RMSE: {:.4f}, Training Time: {:.4f}/epoch'
        print(log.format(i, mtrain_loss, mtrain_mape, mtrain_rmse, mvalid_loss, mvalid_mape, mvalid_rmse, (t2 - t1)), flush=True)
# Out:
# Iter: 000, Train Loss: 0.7925, Train MAE: 0.7925, Train MAPE: 1.3832, Train RMSE: 0.8021
# Epoch: 001, Inference Time: 7.1540 secs
# Epoch: 001, Train Loss: 0.7925, Train MAPE: 1.3832, Train RMSE: 0.8021, Validation Loss: 0.4089, Validation MAPE: 0.8821, Validation RMSE: 0.4301, Training Time: 41.4137/epoch
# Epoch: 001, Inference Time: 15.8888 secs
# Epoch: 001, Train Loss: 0.7014, Train MAPE: 1.2187, Train RMSE: 0.7134, Validation Loss: 0.2521, Validation MAPE: 0.5433, Validation RMSE: 0.2785, Training Time: 94.0153/epoch
# Epoch: 001, Inference Time: 6.5512 secs
# Epoch: 001, Train Loss: 0.6108, Train MAPE: 1.0499, Train RMSE: 0.6237, Validation Loss: 0.1709, Validation MAPE: 0.3690, Validation RMSE: 0.2011, Training Time: 146.3410/epoch
# Epoch: 001, Inference Time: 15.5130 secs
# Epoch: 001, Train Loss: 0.5294, Train MAPE: 0.9054, Train RMSE: 0.5444, Validation Loss: 0.2059, Validation MAPE: 0.4464, Validation RMSE: 0.2639, Training Time: 194.3113/epoch
# Epoch: 001, Inference Time: 4.1856 secs
# Epoch: 001, Train Loss: 0.4658, Train MAPE: 0.8041, Train RMSE: 0.4818, Validation Loss: 0.2934, Validation MAPE: 0.6371, Validation RMSE: 0.3463, Training Time: 248.4430/epoch
# Epoch: 001, Inference Time: 16.2626 secs
# Epoch: 001, Train Loss: 0.4194, Train MAPE: 0.7272, Train RMSE: 0.4365, Validation Loss: 0.3140, Validation MAPE: 0.6816, Validation RMSE: 0.3494, Training Time: 291.6470/epoch
# Epoch: 001, Inference Time: 4.2376 secs
# Epoch: 001, Train Loss: 0.3835, Train MAPE: 0.6684, Train RMSE: 0.4014, Validation Loss: 0.2536, Validation MAPE: 0.5510, Validation RMSE: 0.2884, Training Time: 351.0177/epoch
# Epoch: 001, Inference Time: 16.4835 secs
# Epoch: 001, Train Loss: 0.3553, Train MAPE: 0.6229, Train RMSE: 0.3737, Validation Loss: 0.1858, Validation MAPE: 0.4039, Validation RMSE: 0.2262, Training Time: 395.0293/epoch
# Epoch: 001, Inference Time: 3.0562 secs
# Epoch: 001, Train Loss: 0.3313, Train MAPE: 0.5837, Train RMSE: 0.3503, Validation Loss: 0.1465, Validation MAPE: 0.3180, Validation RMSE: 0.1862, Training Time: 452.7609/epoch
# Iter: 000, Train Loss: 0.1313, Train MAE: 0.1313, Train MAPE: 0.2576, Train RMSE: 0.1532
# Epoch: 002, Inference Time: 16.2586 secs
# Epoch: 002, Train Loss: 0.1313, Train MAPE: 0.2576, Train RMSE: 0.1532, Validation Loss: 0.1320, Validation MAPE: 0.2863, Validation RMSE: 0.1665, Training Time: 39.2913/epoch
# Epoch: 002, Inference Time: 3.7368 secs
# Epoch: 002, Train Loss: 0.1276, Train MAPE: 0.2377, Train RMSE: 0.1478, Validation Loss: 0.1343, Validation MAPE: 0.2911, Validation RMSE: 0.1659, Training Time: 95.5038/epoch
# Epoch: 002, Inference Time: 15.9878 secs
# Epoch: 002, Train Loss: 0.1285, Train MAPE: 0.2398, Train RMSE: 0.1482, Validation Loss: 0.1495, Validation MAPE: 0.3243, Validation RMSE: 0.1818, Training Time: 139.2355/epoch
# Epoch: 002, Inference Time: 3.1002 secs
# Epoch: 002, Train Loss: 0.1251, Train MAPE: 0.2289, Train RMSE: 0.1445, Validation Loss: 0.1650, Validation MAPE: 0.3578, Validation RMSE: 0.1984, Training Time: 196.4155/epoch
# Epoch: 002, Inference Time: 15.4211 secs
# Epoch: 002, Train Loss: 0.1214, Train MAPE: 0.2238, Train RMSE: 0.1407, Validation Loss: 0.1815, Validation MAPE: 0.3938, Validation RMSE: 0.2173, Training Time: 237.6077/epoch
# Epoch: 002, Inference Time: 4.9262 secs
# Epoch: 002, Train Loss: 0.1185, Train MAPE: 0.2187, Train RMSE: 0.1375, Validation Loss: 0.1952, Validation MAPE: 0.4235, Validation RMSE: 0.2337, Training Time: 293.6883/epoch
# Epoch: 002, Inference Time: 16.8792 secs
# Epoch: 002, Train Loss: 0.1211, Train MAPE: 0.2237, Train RMSE: 0.1405, Validation Loss: 0.1942, Validation MAPE: 0.4212, Validation RMSE: 0.2315, Training Time: 335.9079/epoch
# Epoch: 002, Inference Time: 4.1466 secs
# Epoch: 002, Train Loss: 0.1194, Train MAPE: 0.2261, Train RMSE: 0.1391, Validation Loss: 0.1853, Validation MAPE: 0.4019, Validation RMSE: 0.2190, Training Time: 394.3271/epoch
# Epoch: 002, Inference Time: 15.8299 secs
# Epoch: 002, Train Loss: 0.1163, Train MAPE: 0.2197, Train RMSE: 0.1356, Validation Loss: 0.1672, Validation MAPE: 0.3628, Validation RMSE: 0.1957, Training Time: 437.2923/epoch
# Iter: 000, Train Loss: 0.0942, Train MAE: 0.0942, Train MAPE: 0.1631, Train RMSE: 0.1080
# Epoch: 003, Inference Time: 3.8408 secs
# Epoch: 003, Train Loss: 0.0942, Train MAPE: 0.1631, Train RMSE: 0.1080, Validation Loss: 0.1476, Validation MAPE: 0.3204, Validation RMSE: 0.1702, Training Time: 42.0667/epoch
# Epoch: 003, Inference Time: 16.4535 secs
# Epoch: 003, Train Loss: 0.0929, Train MAPE: 0.1636, Train RMSE: 0.1078, Validation Loss: 0.1360, Validation MAPE: 0.2953, Validation RMSE: 0.1561, Training Time: 83.6617/epoch
# Epoch: 003, Inference Time: 4.4454 secs
# Epoch: 003, Train Loss: 0.0982, Train MAPE: 0.1779, Train RMSE: 0.1144, Validation Loss: 0.1332, Validation MAPE: 0.2893, Validation RMSE: 0.1523, Training Time: 139.7822/epoch
# Epoch: 003, Inference Time: 16.1507 secs
# Epoch: 003, Train Loss: 0.1005, Train MAPE: 0.1876, Train RMSE: 0.1172, Validation Loss: 0.1380, Validation MAPE: 0.2998, Validation RMSE: 0.1591, Training Time: 181.1803/epoch
# Epoch: 003, Inference Time: 3.9707 secs
# Epoch: 003, Train Loss: 0.1046, Train MAPE: 0.2077, Train RMSE: 0.1219, Validation Loss: 0.1496, Validation MAPE: 0.3249, Validation RMSE: 0.1745, Training Time: 238.7410/epoch
# Epoch: 003, Inference Time: 16.0257 secs
# Epoch: 003, Train Loss: 0.1025, Train MAPE: 0.2011, Train RMSE: 0.1195, Validation Loss: 0.1634, Validation MAPE: 0.3550, Validation RMSE: 0.1913, Training Time: 280.4649/epoch
# Epoch: 003, Inference Time: 5.2150 secs
# Epoch: 003, Train Loss: 0.1005, Train MAPE: 0.1970, Train RMSE: 0.1173, Validation Loss: 0.1718, Validation MAPE: 0.3732, Validation RMSE: 0.2016, Training Time: 337.4790/epoch
# Epoch: 003, Inference Time: 15.8988 secs
# Epoch: 003, Train Loss: 0.1021, Train MAPE: 0.2010, Train RMSE: 0.1193, Validation Loss: 0.1726, Validation MAPE: 0.3749, Validation RMSE: 0.2028, Training Time: 378.4983/epoch
# Epoch: 003, Inference Time: 4.2545 secs
# Epoch: 003, Train Loss: 0.1021, Train MAPE: 0.2001, Train RMSE: 0.1194, Validation Loss: 0.1663, Validation MAPE: 0.3611, Validation RMSE: 0.1957, Training Time: 434.5549/epoch
# Iter: 000, Train Loss: 0.0901, Train MAE: 0.0901, Train MAPE: 0.1744, Train RMSE: 0.1055
# Epoch: 004, Inference Time: 15.6500 secs
# Epoch: 004, Train Loss: 0.0901, Train MAPE: 0.1744, Train RMSE: 0.1055, Validation Loss: 0.1567, Validation MAPE: 0.3403, Validation RMSE: 0.1848, Training Time: 37.3984/epoch
# Epoch: 004, Inference Time: 5.1200 secs
# Epoch: 004, Train Loss: 0.0870, Train MAPE: 0.1681, Train RMSE: 0.1021, Validation Loss: 0.1450, Validation MAPE: 0.3149, Validation RMSE: 0.1713, Training Time: 94.2675/epoch
# Epoch: 004, Inference Time: 13.0065 secs
# Epoch: 004, Train Loss: 0.0966, Train MAPE: 0.1854, Train RMSE: 0.1129, Validation Loss: 0.1387, Validation MAPE: 0.3011, Validation RMSE: 0.1637, Training Time: 138.3950/epoch
# Epoch: 004, Inference Time: 7.4387 secs
# Epoch: 004, Train Loss: 0.0957, Train MAPE: 0.1849, Train RMSE: 0.1118, Validation Loss: 0.1395, Validation MAPE: 0.3029, Validation RMSE: 0.1643, Training Time: 192.2359/epoch
# Epoch: 004, Inference Time: 13.4132 secs
# Epoch: 004, Train Loss: 0.0932, Train MAPE: 0.1777, Train RMSE: 0.1094, Validation Loss: 0.1457, Validation MAPE: 0.3164, Validation RMSE: 0.1710, Training Time: 236.2155/epoch
# Epoch: 004, Inference Time: 9.7104 secs
# Epoch: 004, Train Loss: 0.0917, Train MAPE: 0.1742, Train RMSE: 0.1077, Validation Loss: 0.1577, Validation MAPE: 0.3424, Validation RMSE: 0.1841, Training Time: 290.7999/epoch
# Epoch: 004, Inference Time: 12.3529 secs
# Epoch: 004, Train Loss: 0.0904, Train MAPE: 0.1722, Train RMSE: 0.1060, Validation Loss: 0.1684, Validation MAPE: 0.3656, Validation RMSE: 0.1962, Training Time: 336.3536/epoch
# Epoch: 004, Inference Time: 8.5161 secs
# Epoch: 004, Train Loss: 0.0911, Train MAPE: 0.1796, Train RMSE: 0.1071, Validation Loss: 0.1749, Validation MAPE: 0.3796, Validation RMSE: 0.2031, Training Time: 391.2919/epoch
# Epoch: 004, Inference Time: 12.0950 secs
# Epoch: 004, Train Loss: 0.0916, Train MAPE: 0.1812, Train RMSE: 0.1077, Validation Loss: 0.1737, Validation MAPE: 0.3771, Validation RMSE: 0.2008, Training Time: 436.0900/epoch
# Iter: 000, Train Loss: 0.0898, Train MAE: 0.0898, Train MAPE: 0.1625, Train RMSE: 0.1049
# Epoch: 005, Inference Time: 8.8849 secs
# Epoch: 005, Train Loss: 0.0898, Train MAPE: 0.1625, Train RMSE: 0.1049, Validation Loss: 0.1637, Validation MAPE: 0.3553, Validation RMSE: 0.1882, Training Time: 40.0768/epoch
# Epoch: 005, Inference Time: 11.7022 secs
# Epoch: 005, Train Loss: 0.0861, Train MAPE: 0.1598, Train RMSE: 0.1002, Validation Loss: 0.1492, Validation MAPE: 0.3240, Validation RMSE: 0.1717, Training Time: 85.0109/epoch
# Epoch: 005, Inference Time: 9.2217 secs
# Epoch: 005, Train Loss: 0.0831, Train MAPE: 0.1526, Train RMSE: 0.0973, Validation Loss: 0.1426, Validation MAPE: 0.3097, Validation RMSE: 0.1645, Training Time: 136.7760/epoch
# Epoch: 005, Inference Time: 11.5803 secs
# Epoch: 005, Train Loss: 0.0803, Train MAPE: 0.1464, Train RMSE: 0.0937, Validation Loss: 0.1430, Validation MAPE: 0.3106, Validation RMSE: 0.1656, Training Time: 181.2303/epoch
# Epoch: 005, Inference Time: 10.2631 secs
# Epoch: 005, Train Loss: 0.0834, Train MAPE: 0.1575, Train RMSE: 0.0976, Validation Loss: 0.1507, Validation MAPE: 0.3273, Validation RMSE: 0.1759, Training Time: 232.9654/epoch
# Epoch: 005, Inference Time: 11.0086 secs
# Epoch: 005, Train Loss: 0.0846, Train MAPE: 0.1612, Train RMSE: 0.0990, Validation Loss: 0.1584, Validation MAPE: 0.3439, Validation RMSE: 0.1863, Training Time: 279.6554/epoch
# Epoch: 005, Inference Time: 11.9441 secs
# Epoch: 005, Train Loss: 0.0853, Train MAPE: 0.1640, Train RMSE: 0.0999, Validation Loss: 0.1659, Validation MAPE: 0.3603, Validation RMSE: 0.1959, Training Time: 332.2360/epoch
# Epoch: 005, Inference Time: 10.8098 secs
# Epoch: 005, Train Loss: 0.0864, Train MAPE: 0.1664, Train RMSE: 0.1014, Validation Loss: 0.1716, Validation MAPE: 0.3728, Validation RMSE: 0.2024, Training Time: 381.2777/epoch
# Epoch: 005, Inference Time: 12.0500 secs
# Epoch: 005, Train Loss: 0.0885, Train MAPE: 0.1777, Train RMSE: 0.1040, Validation Loss: 0.1736, Validation MAPE: 0.3770, Validation RMSE: 0.2045, Training Time: 434.5579/epoch
# Iter: 000, Train Loss: 0.0692, Train MAE: 0.0692, Train MAPE: 0.1271, Train RMSE: 0.0820
# Epoch: 006, Inference Time: 8.3991 secs
# Epoch: 006, Train Loss: 0.0692, Train MAPE: 0.1271, Train RMSE: 0.0820, Validation Loss: 0.1656, Validation MAPE: 0.3596, Validation RMSE: 0.1949, Training Time: 37.4833/epoch
# Epoch: 006, Inference Time: 14.0359 secs
# Epoch: 006, Train Loss: 0.0706, Train MAPE: 0.1299, Train RMSE: 0.0830, Validation Loss: 0.1493, Validation MAPE: 0.3242, Validation RMSE: 0.1752, Training Time: 87.7673/epoch
# Epoch: 006, Inference Time: 7.9234 secs
# Epoch: 006, Train Loss: 0.0807, Train MAPE: 0.1503, Train RMSE: 0.0949, Validation Loss: 0.1369, Validation MAPE: 0.2974, Validation RMSE: 0.1601, Training Time: 139.6563/epoch
# Epoch: 006, Inference Time: 14.1318 secs
# Epoch: 006, Train Loss: 0.0798, Train MAPE: 0.1467, Train RMSE: 0.0940, Validation Loss: 0.1325, Validation MAPE: 0.2879, Validation RMSE: 0.1548, Training Time: 188.3971/epoch
# Epoch: 006, Inference Time: 8.7719 secs
# Epoch: 006, Train Loss: 0.0834, Train MAPE: 0.1624, Train RMSE: 0.0985, Validation Loss: 0.1364, Validation MAPE: 0.2964, Validation RMSE: 0.1595, Training Time: 239.4726/epoch
# Epoch: 006, Inference Time: 13.7730 secs
# Epoch: 006, Train Loss: 0.0863, Train MAPE: 0.1697, Train RMSE: 0.1017, Validation Loss: 0.1505, Validation MAPE: 0.3269, Validation RMSE: 0.1762, Training Time: 288.8451/epoch
# Epoch: 006, Inference Time: 7.4427 secs
# Epoch: 006, Train Loss: 0.0859, Train MAPE: 0.1686, Train RMSE: 0.1011, Validation Loss: 0.1666, Validation MAPE: 0.3617, Validation RMSE: 0.1950, Training Time: 339.0601/epoch
# Epoch: 006, Inference Time: 13.9010 secs
# Epoch: 006, Train Loss: 0.0863, Train MAPE: 0.1689, Train RMSE: 0.1017, Validation Loss: 0.1792, Validation MAPE: 0.3892, Validation RMSE: 0.2099, Training Time: 390.9631/epoch
# Epoch: 006, Inference Time: 10.4729 secs
# Epoch: 006, Train Loss: 0.0861, Train MAPE: 0.1695, Train RMSE: 0.1016, Validation Loss: 0.1849, Validation MAPE: 0.4016, Validation RMSE: 0.2164, Training Time: 439.5910/epoch
# Iter: 000, Train Loss: 0.0872, Train MAE: 0.0872, Train MAPE: 0.1837, Train RMSE: 0.1033
# Epoch: 007, Inference Time: 11.7412 secs
# Epoch: 007, Train Loss: 0.0872, Train MAPE: 0.1837, Train RMSE: 0.1033, Validation Loss: 0.1764, Validation MAPE: 0.3832, Validation RMSE: 0.2061, Training Time: 41.9128/epoch
# Epoch: 007, Inference Time: 9.9712 secs
# Epoch: 007, Train Loss: 0.0872, Train MAPE: 0.1821, Train RMSE: 0.1031, Validation Loss: 0.1627, Validation MAPE: 0.3534, Validation RMSE: 0.1903, Training Time: 90.0020/epoch
# Epoch: 007, Inference Time: 12.7067 secs
# Epoch: 007, Train Loss: 0.0924, Train MAPE: 0.2033, Train RMSE: 0.1087, Validation Loss: 0.1511, Validation MAPE: 0.3281, Validation RMSE: 0.1773, Training Time: 141.6581/epoch
# Epoch: 007, Inference Time: 8.5051 secs
# Epoch: 007, Train Loss: 0.0880, Train MAPE: 0.1868, Train RMSE: 0.1036, Validation Loss: 0.1461, Validation MAPE: 0.3172, Validation RMSE: 0.1719, Training Time: 190.8597/epoch
# Epoch: 007, Inference Time: 11.7692 secs
# Epoch: 007, Train Loss: 0.0869, Train MAPE: 0.1812, Train RMSE: 0.1023, Validation Loss: 0.1516, Validation MAPE: 0.3291, Validation RMSE: 0.1784, Training Time: 241.2906/epoch
# Epoch: 007, Inference Time: 9.6414 secs
# Epoch: 007, Train Loss: 0.0848, Train MAPE: 0.1726, Train RMSE: 0.0998, Validation Loss: 0.1588, Validation MAPE: 0.3448, Validation RMSE: 0.1866, Training Time: 289.8555/epoch
# Epoch: 007, Inference Time: 12.8915 secs
# Epoch: 007, Train Loss: 0.0845, Train MAPE: 0.1720, Train RMSE: 0.0997, Validation Loss: 0.1668, Validation MAPE: 0.3621, Validation RMSE: 0.1952, Training Time: 339.3619/epoch
# Epoch: 007, Inference Time: 8.9918 secs
# Epoch: 007, Train Loss: 0.0835, Train MAPE: 0.1685, Train RMSE: 0.0984, Validation Loss: 0.1729, Validation MAPE: 0.3754, Validation RMSE: 0.2015, Training Time: 388.4865/epoch
# Epoch: 007, Inference Time: 12.0750 secs
# Epoch: 007, Train Loss: 0.0845, Train MAPE: 0.1691, Train RMSE: 0.0996, Validation Loss: 0.1729, Validation MAPE: 0.3754, Validation RMSE: 0.2005, Training Time: 436.8525/epoch
# Iter: 000, Train Loss: 0.0730, Train MAE: 0.0730, Train MAPE: 0.1445, Train RMSE: 0.0862
# Epoch: 008, Inference Time: 8.5521 secs
# Epoch: 008, Train Loss: 0.0730, Train MAPE: 0.1445, Train RMSE: 0.0862, Validation Loss: 0.1674, Validation MAPE: 0.3636, Validation RMSE: 0.1936, Training Time: 37.3324/epoch
# Epoch: 008, Inference Time: 13.1064 secs
# Epoch: 008, Train Loss: 0.0816, Train MAPE: 0.1626, Train RMSE: 0.0961, Validation Loss: 0.1598, Validation MAPE: 0.3470, Validation RMSE: 0.1847, Training Time: 86.6929/epoch
# Epoch: 008, Inference Time: 7.7545 secs
# Epoch: 008, Train Loss: 0.0760, Train MAPE: 0.1495, Train RMSE: 0.0896, Validation Loss: 0.1515, Validation MAPE: 0.3291, Validation RMSE: 0.1756, Training Time: 137.6544/epoch
# Epoch: 008, Inference Time: 13.3623 secs
# Epoch: 008, Train Loss: 0.0771, Train MAPE: 0.1501, Train RMSE: 0.0910, Validation Loss: 0.1434, Validation MAPE: 0.3115, Validation RMSE: 0.1675, Training Time: 186.0995/epoch
# Epoch: 008, Inference Time: 8.7579 secs
# Epoch: 008, Train Loss: 0.0831, Train MAPE: 0.1735, Train RMSE: 0.0980, Validation Loss: 0.1448, Validation MAPE: 0.3145, Validation RMSE: 0.1701, Training Time: 235.9147/epoch
# Epoch: 008, Inference Time: 12.6027 secs
# Epoch: 008, Train Loss: 0.0822, Train MAPE: 0.1686, Train RMSE: 0.0975, Validation Loss: 0.1515, Validation MAPE: 0.3290, Validation RMSE: 0.1790, Training Time: 285.1932/epoch
# Epoch: 008, Inference Time: 8.6650 secs
# Epoch: 008, Train Loss: 0.0801, Train MAPE: 0.1616, Train RMSE: 0.0950, Validation Loss: 0.1539, Validation MAPE: 0.3343, Validation RMSE: 0.1825, Training Time: 334.9444/epoch
# Epoch: 008, Inference Time: 13.2893 secs
# Epoch: 008, Train Loss: 0.0799, Train MAPE: 0.1609, Train RMSE: 0.0946, Validation Loss: 0.1550, Validation MAPE: 0.3367, Validation RMSE: 0.1841, Training Time: 384.2889/epoch
# Epoch: 008, Inference Time: 9.2227 secs
# Epoch: 008, Train Loss: 0.0809, Train MAPE: 0.1629, Train RMSE: 0.0961, Validation Loss: 0.1544, Validation MAPE: 0.3354, Validation RMSE: 0.1824, Training Time: 433.5125/epoch
# Iter: 000, Train Loss: 0.0697, Train MAE: 0.0697, Train MAPE: 0.1447, Train RMSE: 0.0828
# Epoch: 009, Inference Time: 12.1530 secs
# Epoch: 009, Train Loss: 0.0697, Train MAPE: 0.1447, Train RMSE: 0.0828, Validation Loss: 0.1559, Validation MAPE: 0.3387, Validation RMSE: 0.1832, Training Time: 41.1322/epoch
# Epoch: 009, Inference Time: 9.0138 secs
# Epoch: 009, Train Loss: 0.0755, Train MAPE: 0.1515, Train RMSE: 0.0909, Validation Loss: 0.1578, Validation MAPE: 0.3428, Validation RMSE: 0.1846, Training Time: 90.4507/epoch
# Epoch: 009, Inference Time: 13.1344 secs
# Epoch: 009, Train Loss: 0.0776, Train MAPE: 0.1616, Train RMSE: 0.0928, Validation Loss: 0.1607, Validation MAPE: 0.3492, Validation RMSE: 0.1871, Training Time: 140.0860/epoch
# Epoch: 009, Inference Time: 8.7360 secs
# Epoch: 009, Train Loss: 0.0766, Train MAPE: 0.1557, Train RMSE: 0.0915, Validation Loss: 0.1651, Validation MAPE: 0.3585, Validation RMSE: 0.1916, Training Time: 189.0857/epoch
# Epoch: 009, Inference Time: 13.2763 secs
# Epoch: 009, Train Loss: 0.0756, Train MAPE: 0.1520, Train RMSE: 0.0900, Validation Loss: 0.1632, Validation MAPE: 0.3545, Validation RMSE: 0.1893, Training Time: 238.8810/epoch
# Epoch: 009, Inference Time: 7.9914 secs
# Epoch: 009, Train Loss: 0.0773, Train MAPE: 0.1552, Train RMSE: 0.0920, Validation Loss: 0.1584, Validation MAPE: 0.3441, Validation RMSE: 0.1838, Training Time: 289.3248/epoch
# Epoch: 009, Inference Time: 14.6915 secs
# Epoch: 009, Train Loss: 0.0762, Train MAPE: 0.1525, Train RMSE: 0.0907, Validation Loss: 0.1535, Validation MAPE: 0.3335, Validation RMSE: 0.1779, Training Time: 338.5274/epoch
# Epoch: 009, Inference Time: 7.8605 secs
# Epoch: 009, Train Loss: 0.0761, Train MAPE: 0.1562, Train RMSE: 0.0909, Validation Loss: 0.1529, Validation MAPE: 0.3321, Validation RMSE: 0.1770, Training Time: 390.9281/epoch
# Epoch: 009, Inference Time: 13.7610 secs
# Epoch: 009, Train Loss: 0.0775, Train MAPE: 0.1583, Train RMSE: 0.0922, Validation Loss: 0.1557, Validation MAPE: 0.3383, Validation RMSE: 0.1802, Training Time: 440.4335/epoch
# Iter: 000, Train Loss: 0.0626, Train MAE: 0.0626, Train MAPE: 0.1179, Train RMSE: 0.0743
# Epoch: 010, Inference Time: 7.0169 secs
# Epoch: 010, Train Loss: 0.0626, Train MAPE: 0.1179, Train RMSE: 0.0743, Validation Loss: 0.1581, Validation MAPE: 0.3434, Validation RMSE: 0.1831, Training Time: 36.8017/epoch
# Epoch: 010, Inference Time: 15.2822 secs
# Epoch: 010, Train Loss: 0.0754, Train MAPE: 0.1545, Train RMSE: 0.0896, Validation Loss: 0.1675, Validation MAPE: 0.3638, Validation RMSE: 0.1944, Training Time: 84.6651/epoch
# Epoch: 010, Inference Time: 6.0615 secs
# Epoch: 010, Train Loss: 0.0768, Train MAPE: 0.1555, Train RMSE: 0.0910, Validation Loss: 0.1711, Validation MAPE: 0.3714, Validation RMSE: 0.1992, Training Time: 136.6660/epoch
# Epoch: 010, Inference Time: 15.9028 secs
# Epoch: 010, Train Loss: 0.0789, Train MAPE: 0.1569, Train RMSE: 0.0940, Validation Loss: 0.1671, Validation MAPE: 0.3629, Validation RMSE: 0.1949, Training Time: 185.4598/epoch
# Epoch: 010, Inference Time: 5.2979 secs
# Epoch: 010, Train Loss: 0.0791, Train MAPE: 0.1578, Train RMSE: 0.0945, Validation Loss: 0.1645, Validation MAPE: 0.3573, Validation RMSE: 0.1920, Training Time: 240.7379/epoch
# Epoch: 010, Inference Time: 15.8209 secs
# Epoch: 010, Train Loss: 0.0797, Train MAPE: 0.1584, Train RMSE: 0.0947, Validation Loss: 0.1622, Validation MAPE: 0.3524, Validation RMSE: 0.1899, Training Time: 287.5228/epoch
# Epoch: 010, Inference Time: 6.2814 secs
# Epoch: 010, Train Loss: 0.0776, Train MAPE: 0.1529, Train RMSE: 0.0921, Validation Loss: 0.1575, Validation MAPE: 0.3421, Validation RMSE: 0.1848, Training Time: 341.4137/epoch
# Epoch: 010, Inference Time: 15.9398 secs
# Epoch: 010, Train Loss: 0.0768, Train MAPE: 0.1498, Train RMSE: 0.0912, Validation Loss: 0.1536, Validation MAPE: 0.3335, Validation RMSE: 0.1804, Training Time: 389.1911/epoch
# Epoch: 010, Inference Time: 6.1734 secs
# Epoch: 010, Train Loss: 0.0786, Train MAPE: 0.1580, Train RMSE: 0.0931, Validation Loss: 0.1542, Validation MAPE: 0.3350, Validation RMSE: 0.1812, Training Time: 442.1285/epoch
# Iter: 000, Train Loss: 0.0785, Train MAE: 0.0785, Train MAPE: 0.1561, Train RMSE: 0.0935
# Epoch: 011, Inference Time: 15.3092 secs
# Epoch: 011, Train Loss: 0.0785, Train MAPE: 0.1561, Train RMSE: 0.0935, Validation Loss: 0.1583, Validation MAPE: 0.3440, Validation RMSE: 0.1861, Training Time: 40.7964/epoch
# Epoch: 011, Inference Time: 6.0575 secs
# Epoch: 011, Train Loss: 0.0736, Train MAPE: 0.1460, Train RMSE: 0.0871, Validation Loss: 0.1637, Validation MAPE: 0.3555, Validation RMSE: 0.1929, Training Time: 92.6824/epoch
# Epoch: 011, Inference Time: 16.5944 secs
# Epoch: 011, Train Loss: 0.0708, Train MAPE: 0.1380, Train RMSE: 0.0838, Validation Loss: 0.1632, Validation MAPE: 0.3545, Validation RMSE: 0.1926, Training Time: 138.6759/epoch
# Epoch: 011, Inference Time: 5.6767 secs
# Epoch: 011, Train Loss: 0.0727, Train MAPE: 0.1429, Train RMSE: 0.0859, Validation Loss: 0.1587, Validation MAPE: 0.3448, Validation RMSE: 0.1875, Training Time: 191.3434/epoch
# Epoch: 011, Inference Time: 15.4421 secs
# Epoch: 011, Train Loss: 0.0719, Train MAPE: 0.1391, Train RMSE: 0.0855, Validation Loss: 0.1543, Validation MAPE: 0.3352, Validation RMSE: 0.1825, Training Time: 237.0910/epoch
# Epoch: 011, Inference Time: 6.8720 secs
# Epoch: 011, Train Loss: 0.0733, Train MAPE: 0.1437, Train RMSE: 0.0870, Validation Loss: 0.1519, Validation MAPE: 0.3301, Validation RMSE: 0.1801, Training Time: 288.6392/epoch
# Epoch: 011, Inference Time: 15.5310 secs
# Epoch: 011, Train Loss: 0.0763, Train MAPE: 0.1595, Train RMSE: 0.0906, Validation Loss: 0.1577, Validation MAPE: 0.3427, Validation RMSE: 0.1875, Training Time: 336.1617/epoch
# Epoch: 011, Inference Time: 6.0555 secs
# Epoch: 011, Train Loss: 0.0746, Train MAPE: 0.1551, Train RMSE: 0.0885, Validation Loss: 0.1609, Validation MAPE: 0.3495, Validation RMSE: 0.1912, Training Time: 389.0222/epoch
# Epoch: 011, Inference Time: 15.6280 secs
# Epoch: 011, Train Loss: 0.0767, Train MAPE: 0.1578, Train RMSE: 0.0910, Validation Loss: 0.1636, Validation MAPE: 0.3555, Validation RMSE: 0.1940, Training Time: 435.3764/epoch
# Iter: 000, Train Loss: 0.0680, Train MAE: 0.0680, Train MAPE: 0.1216, Train RMSE: 0.0803
# Epoch: 012, Inference Time: 6.3323 secs
# Epoch: 012, Train Loss: 0.0680, Train MAPE: 0.1216, Train RMSE: 0.0803, Validation Loss: 0.1575, Validation MAPE: 0.3422, Validation RMSE: 0.1858, Training Time: 36.2950/epoch
# Epoch: 012, Inference Time: 16.2446 secs
# Epoch: 012, Train Loss: 0.0650, Train MAPE: 0.1225, Train RMSE: 0.0768, Validation Loss: 0.1519, Validation MAPE: 0.3300, Validation RMSE: 0.1778, Training Time: 82.1785/epoch
# Epoch: 012, Inference Time: 5.7807 secs
# Epoch: 012, Train Loss: 0.0704, Train MAPE: 0.1405, Train RMSE: 0.0837, Validation Loss: 0.1519, Validation MAPE: 0.3301, Validation RMSE: 0.1769, Training Time: 135.6816/epoch
# Epoch: 012, Inference Time: 15.6030 secs
# Epoch: 012, Train Loss: 0.0727, Train MAPE: 0.1461, Train RMSE: 0.0864, Validation Loss: 0.1548, Validation MAPE: 0.3363, Validation RMSE: 0.1800, Training Time: 181.8459/epoch
# Epoch: 012, Inference Time: 5.7507 secs
# Epoch: 012, Train Loss: 0.0733, Train MAPE: 0.1464, Train RMSE: 0.0872, Validation Loss: 0.1602, Validation MAPE: 0.3481, Validation RMSE: 0.1867, Training Time: 234.3606/epoch
# Epoch: 012, Inference Time: 15.1622 secs
# Epoch: 012, Train Loss: 0.0722, Train MAPE: 0.1435, Train RMSE: 0.0856, Validation Loss: 0.1646, Validation MAPE: 0.3576, Validation RMSE: 0.1924, Training Time: 280.3620/epoch
# Epoch: 012, Inference Time: 5.2889 secs
# Epoch: 012, Train Loss: 0.0712, Train MAPE: 0.1407, Train RMSE: 0.0844, Validation Loss: 0.1619, Validation MAPE: 0.3518, Validation RMSE: 0.1892, Training Time: 333.1355/epoch
# Epoch: 012, Inference Time: 16.1946 secs
# Epoch: 012, Train Loss: 0.0718, Train MAPE: 0.1418, Train RMSE: 0.0851, Validation Loss: 0.1557, Validation MAPE: 0.3382, Validation RMSE: 0.1816, Training Time: 379.3078/epoch
# Epoch: 012, Inference Time: 5.4768 secs
# Epoch: 012, Train Loss: 0.0764, Train MAPE: 0.1566, Train RMSE: 0.0903, Validation Loss: 0.1559, Validation MAPE: 0.3386, Validation RMSE: 0.1817, Training Time: 432.6700/epoch
# Iter: 000, Train Loss: 0.0855, Train MAE: 0.0855, Train MAPE: 0.1769, Train RMSE: 0.0998
# Epoch: 013, Inference Time: 16.1507 secs
# Epoch: 013, Train Loss: 0.0855, Train MAPE: 0.1769, Train RMSE: 0.0998, Validation Loss: 0.1596, Validation MAPE: 0.3468, Validation RMSE: 0.1864, Training Time: 40.8244/epoch
# Epoch: 013, Inference Time: 4.4724 secs
# Epoch: 013, Train Loss: 0.0840, Train MAPE: 0.1628, Train RMSE: 0.0992, Validation Loss: 0.1626, Validation MAPE: 0.3532, Validation RMSE: 0.1900, Training Time: 95.7187/epoch
# Epoch: 013, Inference Time: 16.0147 secs
# Epoch: 013, Train Loss: 0.0808, Train MAPE: 0.1550, Train RMSE: 0.0957, Validation Loss: 0.1641, Validation MAPE: 0.3565, Validation RMSE: 0.1917, Training Time: 140.1720/epoch
# Epoch: 013, Inference Time: 4.4604 secs
# Epoch: 013, Train Loss: 0.0784, Train MAPE: 0.1524, Train RMSE: 0.0936, Validation Loss: 0.1667, Validation MAPE: 0.3622, Validation RMSE: 0.1947, Training Time: 195.8988/epoch
# Epoch: 013, Inference Time: 15.5600 secs
# Epoch: 013, Train Loss: 0.0791, Train MAPE: 0.1643, Train RMSE: 0.0942, Validation Loss: 0.1677, Validation MAPE: 0.3643, Validation RMSE: 0.1957, Training Time: 240.5000/epoch
# Epoch: 013, Inference Time: 4.8752 secs
# Epoch: 013, Train Loss: 0.0760, Train MAPE: 0.1558, Train RMSE: 0.0903, Validation Loss: 0.1631, Validation MAPE: 0.3544, Validation RMSE: 0.1906, Training Time: 294.7437/epoch
# Epoch: 013, Inference Time: 15.4251 secs
# Epoch: 013, Train Loss: 0.0751, Train MAPE: 0.1546, Train RMSE: 0.0895, Validation Loss: 0.1578, Validation MAPE: 0.3428, Validation RMSE: 0.1845, Training Time: 340.4373/epoch
# Epoch: 013, Inference Time: 3.6629 secs
# Epoch: 013, Train Loss: 0.0760, Train MAPE: 0.1565, Train RMSE: 0.0904, Validation Loss: 0.1544, Validation MAPE: 0.3353, Validation RMSE: 0.1805, Training Time: 396.5069/epoch
# Epoch: 013, Inference Time: 16.3535 secs
# Epoch: 013, Train Loss: 0.0757, Train MAPE: 0.1557, Train RMSE: 0.0902, Validation Loss: 0.1561, Validation MAPE: 0.3390, Validation RMSE: 0.1825, Training Time: 439.8278/epoch
# Iter: 000, Train Loss: 0.0823, Train MAE: 0.0823, Train MAPE: 0.2036, Train RMSE: 0.0985
# Epoch: 014, Inference Time: 3.1282 secs
# Epoch: 014, Train Loss: 0.0823, Train MAPE: 0.2036, Train RMSE: 0.0985, Validation Loss: 0.1638, Validation MAPE: 0.3557, Validation RMSE: 0.1918, Training Time: 40.5066/epoch
# Epoch: 014, Inference Time: 15.4970 secs
# Epoch: 014, Train Loss: 0.0817, Train MAPE: 0.1766, Train RMSE: 0.0985, Validation Loss: 0.1650, Validation MAPE: 0.3585, Validation RMSE: 0.1931, Training Time: 83.0070/epoch
# Epoch: 014, Inference Time: 3.0116 secs
# Epoch: 014, Train Loss: 0.0775, Train MAPE: 0.1598, Train RMSE: 0.0929, Validation Loss: 0.1647, Validation MAPE: 0.3576, Validation RMSE: 0.1922, Training Time: 138.6649/epoch
# Epoch: 014, Inference Time: 2.4186 secs
# Epoch: 014, Train Loss: 0.0741, Train MAPE: 0.1499, Train RMSE: 0.0884, Validation Loss: 0.1636, Validation MAPE: 0.3554, Validation RMSE: 0.1908, Training Time: 165.4567/epoch
# Epoch: 014, Inference Time: 2.4036 secs
# Epoch: 014, Train Loss: 0.0726, Train MAPE: 0.1478, Train RMSE: 0.0863, Validation Loss: 0.1637, Validation MAPE: 0.3556, Validation RMSE: 0.1912, Training Time: 191.9034/epoch
# Epoch: 014, Inference Time: 2.7834 secs
# Epoch: 014, Train Loss: 0.0745, Train MAPE: 0.1514, Train RMSE: 0.0887, Validation Loss: 0.1658, Validation MAPE: 0.3601, Validation RMSE: 0.1938, Training Time: 220.0052/epoch
# Epoch: 014, Inference Time: 2.4716 secs
# Epoch: 014, Train Loss: 0.0724, Train MAPE: 0.1466, Train RMSE: 0.0862, Validation Loss: 0.1618, Validation MAPE: 0.3515, Validation RMSE: 0.1892, Training Time: 246.5788/epoch
# Epoch: 014, Inference Time: 2.3996 secs
# Epoch: 014, Train Loss: 0.0717, Train MAPE: 0.1442, Train RMSE: 0.0855, Validation Loss: 0.1557, Validation MAPE: 0.3383, Validation RMSE: 0.1820, Training Time: 272.9576/epoch
# Epoch: 014, Inference Time: 2.3946 secs
# Epoch: 014, Train Loss: 0.0746, Train MAPE: 0.1525, Train RMSE: 0.0886, Validation Loss: 0.1595, Validation MAPE: 0.3465, Validation RMSE: 0.1866, Training Time: 299.3543/epoch
# Iter: 000, Train Loss: 0.0958, Train MAE: 0.0958, Train MAPE: 0.2168, Train RMSE: 0.1117
# Epoch: 015, Inference Time: 2.7814 secs
# Epoch: 015, Train Loss: 0.0958, Train MAPE: 0.2168, Train RMSE: 0.1117, Validation Loss: 0.1697, Validation MAPE: 0.3685, Validation RMSE: 0.1982, Training Time: 24.6388/epoch
# Epoch: 015, Inference Time: 2.5595 secs
# Epoch: 015, Train Loss: 0.0852, Train MAPE: 0.1866, Train RMSE: 0.1000, Validation Loss: 0.1734, Validation MAPE: 0.3765, Validation RMSE: 0.2023, Training Time: 51.5632/epoch
# Epoch: 015, Inference Time: 2.4666 secs
# Epoch: 015, Train Loss: 0.0760, Train MAPE: 0.1599, Train RMSE: 0.0891, Validation Loss: 0.1662, Validation MAPE: 0.3609, Validation RMSE: 0.1933, Training Time: 78.1288/epoch
# Epoch: 015, Inference Time: 3.5470 secs
# Epoch: 015, Train Loss: 0.0742, Train MAPE: 0.1510, Train RMSE: 0.0869, Validation Loss: 0.1568, Validation MAPE: 0.3403, Validation RMSE: 0.1818, Training Time: 111.9673/epoch
# Epoch: 015, Inference Time: 6.7661 secs
# Epoch: 015, Train Loss: 0.0772, Train MAPE: 0.1564, Train RMSE: 0.0907, Validation Loss: 0.1525, Validation MAPE: 0.3310, Validation RMSE: 0.1767, Training Time: 145.2091/epoch
# Epoch: 015, Inference Time: 3.1432 secs
# Epoch: 015, Train Loss: 0.0777, Train MAPE: 0.1546, Train RMSE: 0.0917, Validation Loss: 0.1583, Validation MAPE: 0.3436, Validation RMSE: 0.1837, Training Time: 205.0015/epoch
# Epoch: 015, Inference Time: 2.4136 secs
# Epoch: 015, Train Loss: 0.0781, Train MAPE: 0.1608, Train RMSE: 0.0923, Validation Loss: 0.1698, Validation MAPE: 0.3687, Validation RMSE: 0.1979, Training Time: 233.6230/epoch
# Epoch: 015, Inference Time: 3.1372 secs
# Epoch: 015, Train Loss: 0.0767, Train MAPE: 0.1564, Train RMSE: 0.0905, Validation Loss: 0.1715, Validation MAPE: 0.3724, Validation RMSE: 0.2007, Training Time: 260.6983/epoch
# Epoch: 015, Inference Time: 2.5145 secs
# Epoch: 015, Train Loss: 0.0752, Train MAPE: 0.1530, Train RMSE: 0.0888, Validation Loss: 0.1631, Validation MAPE: 0.3542, Validation RMSE: 0.1908, Training Time: 290.6810/epoch
# Iter: 000, Train Loss: 0.0890, Train MAE: 0.0890, Train MAPE: 0.1673, Train RMSE: 0.1083
# Epoch: 016, Inference Time: 2.6155 secs
# Epoch: 016, Train Loss: 0.0890, Train MAPE: 0.1673, Train RMSE: 0.1083, Validation Loss: 0.1505, Validation MAPE: 0.3270, Validation RMSE: 0.1760, Training Time: 25.7071/epoch
# Epoch: 016, Inference Time: 2.4776 secs
# Epoch: 016, Train Loss: 0.0846, Train MAPE: 0.1702, Train RMSE: 0.1027, Validation Loss: 0.1475, Validation MAPE: 0.3205, Validation RMSE: 0.1727, Training Time: 56.9151/epoch
# Epoch: 016, Inference Time: 2.3866 secs
# Epoch: 016, Train Loss: 0.0866, Train MAPE: 0.1895, Train RMSE: 0.1041, Validation Loss: 0.1551, Validation MAPE: 0.3371, Validation RMSE: 0.1818, Training Time: 82.9820/epoch
# Epoch: 016, Inference Time: 2.4886 secs
# Epoch: 016, Train Loss: 0.0822, Train MAPE: 0.1769, Train RMSE: 0.0992, Validation Loss: 0.1667, Validation MAPE: 0.3623, Validation RMSE: 0.1950, Training Time: 110.0604/epoch
# Epoch: 016, Inference Time: 2.8653 secs
# Epoch: 016, Train Loss: 0.0800, Train MAPE: 0.1686, Train RMSE: 0.0962, Validation Loss: 0.1677, Validation MAPE: 0.3645, Validation RMSE: 0.1961, Training Time: 137.5575/epoch
# Epoch: 016, Inference Time: 2.4346 secs
# Epoch: 016, Train Loss: 0.0793, Train MAPE: 0.1649, Train RMSE: 0.0951, Validation Loss: 0.1553, Validation MAPE: 0.3374, Validation RMSE: 0.1820, Training Time: 164.4560/epoch
# Epoch: 016, Inference Time: 2.3796 secs
# Epoch: 016, Train Loss: 0.0775, Train MAPE: 0.1588, Train RMSE: 0.0928, Validation Loss: 0.1446, Validation MAPE: 0.3142, Validation RMSE: 0.1695, Training Time: 190.8137/epoch
# Epoch: 016, Inference Time: 2.4076 secs
# Epoch: 016, Train Loss: 0.0754, Train MAPE: 0.1530, Train RMSE: 0.0900, Validation Loss: 0.1437, Validation MAPE: 0.3123, Validation RMSE: 0.1682, Training Time: 217.2385/epoch
# Epoch: 016, Inference Time: 2.7824 secs
# Epoch: 016, Train Loss: 0.0758, Train MAPE: 0.1546, Train RMSE: 0.0906, Validation Loss: 0.1549, Validation MAPE: 0.3366, Validation RMSE: 0.1811, Training Time: 245.8179/epoch
# Iter: 000, Train Loss: 0.0649, Train MAE: 0.0649, Train MAPE: 0.1259, Train RMSE: 0.0759
# Epoch: 017, Inference Time: 2.5815 secs
# Epoch: 017, Train Loss: 0.0649, Train MAPE: 0.1259, Train RMSE: 0.0759, Validation Loss: 0.1681, Validation MAPE: 0.3651, Validation RMSE: 0.1970, Training Time: 24.2140/epoch
# Epoch: 017, Inference Time: 2.4606 secs
# Epoch: 017, Train Loss: 0.0681, Train MAPE: 0.1333, Train RMSE: 0.0820, Validation Loss: 0.1746, Validation MAPE: 0.3793, Validation RMSE: 0.2048, Training Time: 51.4693/epoch
# Epoch: 017, Inference Time: 2.4986 secs
# Epoch: 017, Train Loss: 0.0759, Train MAPE: 0.1745, Train RMSE: 0.0912, Validation Loss: 0.1779, Validation MAPE: 0.3864, Validation RMSE: 0.2090, Training Time: 78.4946/epoch
# Epoch: 017, Inference Time: 2.6155 secs
# Epoch: 017, Train Loss: 0.0782, Train MAPE: 0.1695, Train RMSE: 0.0937, Validation Loss: 0.1662, Validation MAPE: 0.3609, Validation RMSE: 0.1950, Training Time: 106.0807/epoch
# Epoch: 017, Inference Time: 2.5605 secs
# Epoch: 017, Train Loss: 0.0759, Train MAPE: 0.1617, Train RMSE: 0.0907, Validation Loss: 0.1506, Validation MAPE: 0.3270, Validation RMSE: 0.1763, Training Time: 133.3759/epoch
# Epoch: 017, Inference Time: 2.5315 secs
# Epoch: 017, Train Loss: 0.0764, Train MAPE: 0.1618, Train RMSE: 0.0910, Validation Loss: 0.1461, Validation MAPE: 0.3172, Validation RMSE: 0.1707, Training Time: 160.4203/epoch
# Epoch: 017, Inference Time: 2.5895 secs
# Epoch: 017, Train Loss: 0.0745, Train MAPE: 0.1545, Train RMSE: 0.0886, Validation Loss: 0.1503, Validation MAPE: 0.3265, Validation RMSE: 0.1756, Training Time: 187.4976/epoch
# Epoch: 017, Inference Time: 2.5755 secs
# Epoch: 017, Train Loss: 0.0744, Train MAPE: 0.1530, Train RMSE: 0.0884, Validation Loss: 0.1622, Validation MAPE: 0.3523, Validation RMSE: 0.1899, Training Time: 213.9214/epoch
# Epoch: 017, Inference Time: 2.6065 secs
# Epoch: 017, Train Loss: 0.0740, Train MAPE: 0.1514, Train RMSE: 0.0878, Validation Loss: 0.1770, Validation MAPE: 0.3845, Validation RMSE: 0.2078, Training Time: 241.0567/epoch
# Iter: 000, Train Loss: 0.0799, Train MAE: 0.0799, Train MAPE: 0.2097, Train RMSE: 0.0965
# Epoch: 018, Inference Time: 2.4016 secs
# Epoch: 018, Train Loss: 0.0799, Train MAPE: 0.2097, Train RMSE: 0.0965, Validation Loss: 0.1788, Validation MAPE: 0.3884, Validation RMSE: 0.2100, Training Time: 24.7237/epoch
# Epoch: 018, Inference Time: 2.5575 secs
# Epoch: 018, Train Loss: 0.0744, Train MAPE: 0.1740, Train RMSE: 0.0894, Validation Loss: 0.1674, Validation MAPE: 0.3635, Validation RMSE: 0.1961, Training Time: 51.2634/epoch
# Epoch: 018, Inference Time: 2.6335 secs
# Epoch: 018, Train Loss: 0.0724, Train MAPE: 0.1588, Train RMSE: 0.0872, Validation Loss: 0.1501, Validation MAPE: 0.3260, Validation RMSE: 0.1746, Training Time: 78.6665/epoch
# Epoch: 018, Inference Time: 2.4946 secs
# Epoch: 018, Train Loss: 0.0728, Train MAPE: 0.1533, Train RMSE: 0.0868, Validation Loss: 0.1458, Validation MAPE: 0.3167, Validation RMSE: 0.1693, Training Time: 105.3071/epoch
# Epoch: 018, Inference Time: 2.4596 secs
# Epoch: 018, Train Loss: 0.0747, Train MAPE: 0.1535, Train RMSE: 0.0890, Validation Loss: 0.1539, Validation MAPE: 0.3342, Validation RMSE: 0.1792, Training Time: 131.7768/epoch
# Epoch: 018, Inference Time: 2.6815 secs
# Epoch: 018, Train Loss: 0.0721, Train MAPE: 0.1461, Train RMSE: 0.0859, Validation Loss: 0.1688, Validation MAPE: 0.3667, Validation RMSE: 0.1971, Training Time: 159.4279/epoch
# Epoch: 018, Inference Time: 2.6814 secs
# Epoch: 018, Train Loss: 0.0706, Train MAPE: 0.1432, Train RMSE: 0.0840, Validation Loss: 0.1752, Validation MAPE: 0.3805, Validation RMSE: 0.2046, Training Time: 186.4023/epoch
# Epoch: 018, Inference Time: 2.4636 secs
# Epoch: 018, Train Loss: 0.0728, Train MAPE: 0.1488, Train RMSE: 0.0867, Validation Loss: 0.1753, Validation MAPE: 0.3809, Validation RMSE: 0.2042, Training Time: 213.3637/epoch
# Epoch: 018, Inference Time: 2.4016 secs
# Epoch: 018, Train Loss: 0.0742, Train MAPE: 0.1544, Train RMSE: 0.0881, Validation Loss: 0.1718, Validation MAPE: 0.3732, Validation RMSE: 0.1999, Training Time: 240.4420/epoch
# Iter: 000, Train Loss: 0.0800, Train MAE: 0.0800, Train MAPE: 0.1826, Train RMSE: 0.0950
# Epoch: 019, Inference Time: 2.6445 secs
# Epoch: 019, Train Loss: 0.0800, Train MAPE: 0.1826, Train RMSE: 0.0950, Validation Loss: 0.1638, Validation MAPE: 0.3558, Validation RMSE: 0.1903, Training Time: 25.5452/epoch
# Epoch: 019, Inference Time: 2.7834 secs
# Epoch: 019, Train Loss: 0.0777, Train MAPE: 0.1644, Train RMSE: 0.0920, Validation Loss: 0.1562, Validation MAPE: 0.3393, Validation RMSE: 0.1815, Training Time: 52.6876/epoch
# Epoch: 019, Inference Time: 2.4976 secs
# Epoch: 019, Train Loss: 0.0716, Train MAPE: 0.1476, Train RMSE: 0.0849, Validation Loss: 0.1502, Validation MAPE: 0.3262, Validation RMSE: 0.1744, Training Time: 79.5860/epoch
# Epoch: 019, Inference Time: 2.4046 secs
# Epoch: 019, Train Loss: 0.0688, Train MAPE: 0.1382, Train RMSE: 0.0817, Validation Loss: 0.1535, Validation MAPE: 0.3334, Validation RMSE: 0.1787, Training Time: 105.7209/epoch
# Epoch: 019, Inference Time: 2.4406 secs
# Epoch: 019, Train Loss: 0.0687, Train MAPE: 0.1369, Train RMSE: 0.0812, Validation Loss: 0.1658, Validation MAPE: 0.3601, Validation RMSE: 0.1933, Training Time: 132.3875/epoch
# Epoch: 019, Inference Time: 2.6185 secs
# Epoch: 019, Train Loss: 0.0668, Train MAPE: 0.1325, Train RMSE: 0.0790, Validation Loss: 0.1754, Validation MAPE: 0.3811, Validation RMSE: 0.2050, Training Time: 159.6138/epoch
# Epoch: 019, Inference Time: 2.5575 secs
# Epoch: 019, Train Loss: 0.0734, Train MAPE: 0.1543, Train RMSE: 0.0863, Validation Loss: 0.1842, Validation MAPE: 0.4000, Validation RMSE: 0.2155, Training Time: 188.2082/epoch
# Epoch: 019, Inference Time: 2.5465 secs
# Epoch: 019, Train Loss: 0.0738, Train MAPE: 0.1541, Train RMSE: 0.0871, Validation Loss: 0.1763, Validation MAPE: 0.3830, Validation RMSE: 0.2067, Training Time: 215.0247/epoch
# Epoch: 019, Inference Time: 2.5575 secs
# Epoch: 019, Train Loss: 0.0733, Train MAPE: 0.1525, Train RMSE: 0.0868, Validation Loss: 0.1600, Validation MAPE: 0.3476, Validation RMSE: 0.1879, Training Time: 241.2866/epoch
# Iter: 000, Train Loss: 0.0662, Train MAE: 0.0662, Train MAPE: 0.1331, Train RMSE: 0.0796
# Epoch: 020, Inference Time: 2.3716 secs
# Epoch: 020, Train Loss: 0.0662, Train MAPE: 0.1331, Train RMSE: 0.0796, Validation Loss: 0.1500, Validation MAPE: 0.3257, Validation RMSE: 0.1756, Training Time: 24.2400/epoch
# Epoch: 020, Inference Time: 2.5695 secs
# Epoch: 020, Train Loss: 0.0685, Train MAPE: 0.1309, Train RMSE: 0.0812, Validation Loss: 0.1479, Validation MAPE: 0.3213, Validation RMSE: 0.1730, Training Time: 51.5952/epoch
# Epoch: 020, Inference Time: 2.6964 secs
# Epoch: 020, Train Loss: 0.0766, Train MAPE: 0.1504, Train RMSE: 0.0913, Validation Loss: 0.1554, Validation MAPE: 0.3374, Validation RMSE: 0.1816, Training Time: 78.9864/epoch
# Epoch: 020, Inference Time: 2.3257 secs
# Epoch: 020, Train Loss: 0.0766, Train MAPE: 0.1506, Train RMSE: 0.0910, Validation Loss: 0.1746, Validation MAPE: 0.3792, Validation RMSE: 0.2041, Training Time: 106.6324/epoch
# Epoch: 020, Inference Time: 2.6994 secs
# Epoch: 020, Train Loss: 0.0749, Train MAPE: 0.1475, Train RMSE: 0.0893, Validation Loss: 0.1829, Validation MAPE: 0.3973, Validation RMSE: 0.2141, Training Time: 134.8831/epoch
# Epoch: 020, Inference Time: 2.6525 secs
# Epoch: 020, Train Loss: 0.0761, Train MAPE: 0.1586, Train RMSE: 0.0905, Validation Loss: 0.1824, Validation MAPE: 0.3962, Validation RMSE: 0.2136, Training Time: 161.9504/epoch
# Epoch: 020, Inference Time: 2.4316 secs
# Epoch: 020, Train Loss: 0.0771, Train MAPE: 0.1589, Train RMSE: 0.0913, Validation Loss: 0.1652, Validation MAPE: 0.3589, Validation RMSE: 0.1932, Training Time: 188.7729/epoch
# Epoch: 020, Inference Time: 2.3127 secs
# Epoch: 020, Train Loss: 0.0752, Train MAPE: 0.1546, Train RMSE: 0.0890, Validation Loss: 0.1506, Validation MAPE: 0.3270, Validation RMSE: 0.1752, Training Time: 215.2786/epoch
# Epoch: 020, Inference Time: 2.4636 secs
# Epoch: 020, Train Loss: 0.0749, Train MAPE: 0.1530, Train RMSE: 0.0884, Validation Loss: 0.1439, Validation MAPE: 0.3127, Validation RMSE: 0.1673, Training Time: 242.1880/epoch

# %%
validpredlist = []
for eachgroup in his_valid_pred[len(his_valid_pred)-1]:
    for eachteam in eachgroup:
        for i in range(0,96):
            validpredlist.append(eachteam[0][i].item())           
validpred = np.array(validpredlist)
validpred = validpred[0:480]

## load yvalid
yvaliddf = pd.read_excel("yvalid.xlsx")
yori_valid = np.array(yvaliddf['Yori'])
ynorm_valid = np.array(yvaliddf['Ystar'])

aa_valid = yori_valid
bb_valid = (np.max(yori_valid) - np.min(yori_valid))*validpred + np.min(yori_valid)
cc_valid = ynorm_valid

# valid R2
expvar1 = np.sum((cc_valid - validpred)**2)
expvar2 = np.sum((cc_valid - np.mean(cc_valid))**2)
validR2 = 1 - expvar1/expvar2

# valid rmse
validrmse = math.sqrt(np.mean(np.square(aa_valid - bb_valid)))

# %%
validR2
# Out:
# 0.5734944515145726

# %%
validrmse
# Out:
# 4.59443023578046

# %%
storelist = ['Valid'] + list(validpred)
storelist = np.array(storelist)
np.savetxt('Valid.txt', storelist, fmt="%s", delimiter=',')

# %%
import argparse
import time
import math
import csv
import pandas as pd
from util import *
from layer import *
from trainer import DoubleTrainer
from HierNet import HierarchicalNet
from datetime import datetime

# %%
def str_to_bool(value):
    if isinstance(value, bool):
        return value
    if value.lower() in {'false', 'f', '0', 'no', 'n'}:
        return False
    elif value.lower() in {'true', 't', '1', 'yes', 'y'}:
        return True
    raise ValueError(f'{value} is not a valid boolean value')

## --gcn_depth 2 --num_var 4 --var_nodes 4 --stat_nodes 96 --var_node_dim 10 --stat_node_dim 10 --seq_in_len 26 --seq_out_len 1 --batch_size 4 --tanhalpha 2

######################################### Illinois settings ###################################
parser = argparse.ArgumentParser()

parser.add_argument('--device',type=str,default='cpu',help='')
parser.add_argument('--dir',type=str,default='',help='data path')
parser.add_argument('--data_name',type=str,default='Illinois',help='dataset name')

parser.add_argument('--hier_true', type=str_to_bool, default=False, help='whether to use flat graph')
parser.add_argument('--DIL_true', type=str_to_bool, default=True, help='whether to use Dynamic Interaction learning')
parser.add_argument('--gcn_true', type=str_to_bool, default=True, help='whether to add graph convolution layer')
parser.add_argument('--gat_true', type=str_to_bool, default=False, help='whether to add graph attention layer')
parser.add_argument('--buildA_true', type=str_to_bool, default=True, help='whether to construct adaptive adjacency matrix')

parser.add_argument('--gcn_depth',type=int,default=2,help='graph convolution depth')
parser.add_argument('--num_var', type=int, default=4,help='var num during encoding phrase for ablation study') 
parser.add_argument('--var_nodes',type=int,default=4,help='number of nodes/indices')
parser.add_argument('--stat_nodes',type=int,default=96,help='number of nodes/locations')
parser.add_argument('--num_heads',type=int,default=4,help='number of multi-head for graph attention') 
parser.add_argument('--dropout',type=float,default=0.3,help='dropout rate')
parser.add_argument('--var_node_dim',type=int,default=20,help='dim of nodes') 
parser.add_argument('--stat_node_dim',type=int,default=20,help='dim of nodes') 
parser.add_argument('--dilation_exponential',type=int,default=1,help='dilation exponential')

parser.add_argument('--conv_channels',type=int,default=16,help='convolution channels') 
parser.add_argument('--residual_channels',type=int,default=16,help='residual channels') 
parser.add_argument('--skip_channels',type=int,default=32,help='skip channels') 
parser.add_argument('--end_channels',type=int,default=64,help='end channels') 

parser.add_argument('--in_dim',type=int,default=2,help='inputs dimension')  
parser.add_argument('--seq_in_len',type=int,default=26,help='input sequence length')
parser.add_argument('--seq_out_len',type=int,default=1,help='output sequence length') ### can be 1 or not

parser.add_argument('--layers',type=int,default=3,help='number of layers')
parser.add_argument('--batch_size',type=int,default=4,help='batch size')
parser.add_argument('--learning_rate',type=float,default=0.001,help='learning rate')
parser.add_argument('--propalpha',type=float,default=0.05,help='prop alpha')
parser.add_argument('--tanhalpha',type=float,default=1,help='adj alpha')
parser.add_argument('--weight_decay',type=float,default=0.0001,help='weight decay rate')
parser.add_argument('--clip',type=int,default=5,help='clip')

parser.add_argument('--step_size1',type=int,default=1,help='step_size')
parser.add_argument('--step_size2',type=int,default=100,help='step_size')

parser.add_argument('--epochs',type=int,default=20,help='num of train epoch')
parser.add_argument('--print_every',type=int,default=10,help='print information every n iteration')
parser.add_argument('--seed',type=int,default=101,help='random seed')
#parser.add_argument('--patient',type=int,default=10,help='early stop')

parser.add_argument('--expid',type=int,default=1,help='experiment id')
parser.add_argument('--runs',type=int,default=1,help='number of runs')

args, unknown = parser.parse_known_args()
torch.set_num_threads(3)

# %%
runid = 1
torch.manual_seed(args.seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(args.seed)

# load data
device = torch.device(args.device)
dir = args.dir

from helper import load_pkl  
from util import DataLoaderM 

def load_Illinois_dataset(dataset_dir, dictname, batch_size, device='cpu'):

    ori_data = load_pkl(dataset_dir, dictname)
    
    data = {}
    for category in ['train', 'val', 'test']:
        tmpilli = ori_data['x_' + category]
        num_year, num_sample, num_variables, num_column = tmpilli.shape  ## num_sample is the number of rows in one year (26*number of counties)

        ## reshape x_category
        allinlist =[]
        num_week = 26
        num_county = 96
        for eachyear in tmpilli:
            for eachweek in eachyear:
                for eachindex in eachweek:
                    allinlist.append(eachindex[3])       
        Yearlist = []
        for i in range(1, num_year +1):
            x = allinlist[(i-1)*num_sample*num_variables : i*num_sample*num_variables]
            Yearlist.append(x)
        Countylist = []
        for eachyear in Yearlist:    
            for i in range(1, num_county +1):
                x = eachyear[(i-1)*num_week*num_variables : i*num_week*num_variables]
                Countylist.append(x)
        Weeklist = []
        for ii in range(20, 45+1):
            for eachcounty in Countylist:
                x = eachcounty[(ii-20)*num_variables : (ii-20+1)*num_variables]
                Weeklist.append(x)
        Weeksequence = []
        for ii in range(1, num_year +1):
            for j in range(1, num_week +1):
                x = Weeklist[(ii-1)*num_county + (j-1)*num_year*num_county : (ii-1)*num_county + (j-1)*num_year*num_county + num_county]
                Weeksequence.append(x)
        Yearweeksequence = []
        for i in range(1, num_year + 1):
            Yearweeksequence.append(Weeksequence[(i-1)*num_week : i*num_week])
        x_array = np.array(Yearweeksequence)
        tmp = x_array
        num_years, num_weeks, num_counties, num_indices = tmp.shape
        tmp = np.expand_dims(tmp, axis=-1)
        tmp_list = [tmp]
        time_ind = [(i % 26) / 26 for i in range(num_weeks)]  # week in year
        time_ind = np.array(time_ind) # 26
        week_in_year = np.tile(time_ind, [num_years, 1, num_counties, num_indices, 1]).transpose((0, 4, 2, 3, 1))
        tmp_list.append(week_in_year)
        data['x_' + category] = np.concatenate(tmp_list, axis=-1)

        ## reshape y_category
        tmp_y = ori_data['y_' + category]
        allyieldlist = []
        for eachline in tmp_y:    
            allyieldlist.append(eachline[2])
        Yearyieldlist = []
        for ii in range(1, num_years +1):
            x = allyieldlist[(ii-1)*num_counties : ii*num_counties]
            Yearyieldlist.append(x)
        y_array = np.array(Yearyieldlist)
        data['y_' + category] = np.expand_dims(y_array, axis=-1) # [year, county, yield]

    data['train_loader'] = DataLoaderM(data['x_train'], data['y_train'], batch_size)
    data['val_loader'] = DataLoaderM(data['x_val'], data['y_val'], batch_size)
    data['test_loader'] = DataLoaderM(data['x_test'], data['y_test'], batch_size)

    return data
    
# Illinois
dataloader = load_Illinois_dataset(dataset_dir = args.dir, dictname = 'illi_data_sepanormal_temporal.dict', batch_size = args.batch_size, device=args.device)

if args.data_name == "Illinois":
   conv_k_size = (1, 4, 1)


model = HierarchicalNet(seq_length=args.seq_in_len, n_var=args.var_nodes, n_stat=args.stat_nodes, var_dim=args.var_node_dim,
                        stat_dim=args.stat_node_dim, device=args.device, tanhalpha=args.tanhalpha, conv_channels=args.conv_channels,
                        gcn_depth=args.gcn_depth, residual_channels=args.residual_channels, in_dim=args.in_dim,
                        dropout=args.dropout, end_channels=args.end_channels, out_dim=args.seq_out_len,
                        propalpha=args.propalpha, predefined_A=args.buildA_true, static_feat=None, dilation_exponential=args.dilation_exponential,
                        layers=args.layers, layer_norm_affline=True, skip_channels=args.skip_channels,
                        gcn_true=args.gcn_true, gat_true=args.gat_true, num_heads = args.num_heads, hier_true=args.hier_true, DIL_true=args.DIL_true, conv_k_size=conv_k_size)

print(args)
print('The receptive field size is', model.receptive_field)
nParams = sum([p.nelement() for p in model.parameters()])
print('Number of model parameters is', nParams)

engine = DoubleTrainer(model, args.learning_rate, args.weight_decay, args.clip, args.step_size1, args.seq_out_len, device=args.device)

print("start training...",flush=True)
# Out:
# illi_data_sepanormal_temporal.dict  is loaded from:
# Namespace(device='cpu', dir='', data_name='Illinois', hier_true=False, DIL_true=True, gcn_true=True, gat_true=False, buildA_true=True, gcn_depth=2, num_var=4, var_nodes=4, stat_nodes=96, num_heads=4, dropout=0.3, var_node_dim=20, stat_node_dim=20, dilation_exponential=1, conv_channels=16, residual_channels=16, skip_channels=32, end_channels=64, in_dim=2, seq_in_len=26, seq_out_len=1, layers=3, batch_size=4, learning_rate=0.001, propalpha=0.05, tanhalpha=1, weight_decay=0.0001, clip=5, step_size1=1, step_size2=100, epochs=20, print_every=10, seed=101, expid=1, runs=1)
# The receptive field size is 16
# Number of model parameters is 1780870
# start training...

# %%
## validation loss

his_train_loss = []
his_valid_loss =[]
his_valid_rmse = []
his_valid_pred = []
train_time = []
valid_time = []

for i in range(1,args.epochs+1):# epochs   
    
    train_loss = []
    train_mae = []
    train_mape = []
    train_rmse = []
    t1 = time.time()
    
    dataloader['train_loader'].shuffle() # shuffle train_loader data
    
    for iter, (x, y) in enumerate(dataloader['train_loader'].get_iterator()):
        trainx = torch.Tensor(x).to(device)
        trainx = trainx.transpose(1, 4)
        trainy = torch.Tensor(y).to(device)
        metrics = engine.train(trainx, trainy, iter, data_name=args.data_name)
        train_loss.append(metrics[0])
        train_mae.append(metrics[1])
        train_mape.append(metrics[2])
        train_rmse.append(metrics[3])
    
        if iter % args.print_every == 0 :
            log = 'Iter: {:03d}, Train Loss: {:.4f}, Train MAE: {:.4f}, Train MAPE: {:.4f}, Train RMSE: {:.4f}'
            print(log.format(iter, train_loss[-1], train_mae[-1], train_mape[-1], train_rmse[-1]),flush=True)
    
        t2 = time.time()
        train_time.append(t2-t1)
    
        # validation data
        valid_mae = []
        valid_mape = []
        valid_rmse = []
        valid_pred = []
    
        s1 = time.time()
        for iter, (x, y) in enumerate(dataloader['test_loader'].get_iterator()):
            validx = torch.Tensor(x).to(device)
            validx = validx.transpose(1, 4)
            validy = torch.Tensor(y).to(device)

            if i !=20 :
               metrics = engine.eval(validx, validy, data_name=args.data_name) # first reduce, then expand y:(batch, variables, time)
               valid_mae.append(metrics[0])
               valid_mape.append(metrics[1])
               valid_rmse.append(metrics[2])
            else:    
               metrics = engine.evalbest(validx, validy, data_name=args.data_name) # first reduce, then expand y:(batch, variables, time)
               valid_mae.append(metrics[0])
               valid_mape.append(metrics[1])
               valid_rmse.append(metrics[2])
               valid_pred.append(metrics[3])                    
            
        s2 = time.time()
        log = 'Epoch: {:03d}, Inference Time: {:.4f} secs'
        print(log.format(i,(s2-s1)))
        valid_time.append(s2-s1)
    
        mtrain_loss = np.mean(train_loss)
        mtrain_mape = np.mean(train_mape)
        mtrain_rmse = np.mean(train_rmse)
        his_train_loss.append(mtrain_loss)
    
        mvalid_loss = np.mean(valid_mae)
        mvalid_mape = np.mean(valid_mape)
        mvalid_rmse = np.mean(valid_rmse)
        his_valid_loss.append(mvalid_loss)
        his_valid_rmse.append(mvalid_rmse)
        his_valid_pred.append(valid_pred)
    
        log = 'Epoch: {:03d}, Train Loss: {:.4f}, Train MAPE: {:.4f}, Train RMSE: {:.4f}, Validation Loss: {:.4f}, ' \
              'Validation MAPE: {:.4f}, Validation RMSE: {:.4f}, Training Time: {:.4f}/epoch'
        print(log.format(i, mtrain_loss, mtrain_mape, mtrain_rmse, mvalid_loss, mvalid_mape, mvalid_rmse, (t2 - t1)), flush=True)
# Out:
# Iter: 000, Train Loss: 0.7925, Train MAE: 0.7925, Train MAPE: 1.3832, Train RMSE: 0.8021
# Epoch: 001, Inference Time: 1.5641 secs
# Epoch: 001, Train Loss: 0.7925, Train MAPE: 1.3832, Train RMSE: 0.8021, Validation Loss: 0.3664, Validation MAPE: 0.8725, Validation RMSE: 0.3897, Training Time: 29.0552/epoch
# Epoch: 001, Inference Time: 1.8020 secs
# Epoch: 001, Train Loss: 0.7014, Train MAPE: 1.2187, Train RMSE: 0.7134, Validation Loss: 0.2184, Validation MAPE: 0.5181, Validation RMSE: 0.2462, Training Time: 58.9105/epoch
# Epoch: 001, Inference Time: 5.8206 secs
# Epoch: 001, Train Loss: 0.6108, Train MAPE: 1.0499, Train RMSE: 0.6237, Validation Loss: 0.1633, Validation MAPE: 0.3909, Validation RMSE: 0.1989, Training Time: 108.5198/epoch
# Epoch: 001, Inference Time: 1.5291 secs
# Epoch: 001, Train Loss: 0.5294, Train MAPE: 0.9054, Train RMSE: 0.5444, Validation Loss: 0.2302, Validation MAPE: 0.5594, Validation RMSE: 0.2913, Training Time: 144.2521/epoch
# Epoch: 001, Inference Time: 1.6141 secs
# Epoch: 001, Train Loss: 0.4658, Train MAPE: 0.8041, Train RMSE: 0.4818, Validation Loss: 0.3339, Validation MAPE: 0.8131, Validation RMSE: 0.3841, Training Time: 171.7942/epoch
# Epoch: 001, Inference Time: 1.6251 secs
# Epoch: 001, Train Loss: 0.4194, Train MAPE: 0.7272, Train RMSE: 0.4365, Validation Loss: 0.3580, Validation MAPE: 0.8718, Validation RMSE: 0.3915, Training Time: 223.7042/epoch
# Epoch: 001, Inference Time: 1.5131 secs
# Epoch: 001, Train Loss: 0.3835, Train MAPE: 0.6684, Train RMSE: 0.4014, Validation Loss: 0.2974, Validation MAPE: 0.7254, Validation RMSE: 0.3309, Training Time: 251.9599/epoch
# Epoch: 001, Inference Time: 1.7530 secs
# Epoch: 001, Train Loss: 0.3553, Train MAPE: 0.6229, Train RMSE: 0.3737, Validation Loss: 0.2261, Validation MAPE: 0.5526, Validation RMSE: 0.2648, Training Time: 279.5360/epoch
# Epoch: 001, Inference Time: 1.4741 secs
# Epoch: 001, Train Loss: 0.3313, Train MAPE: 0.5837, Train RMSE: 0.3503, Validation Loss: 0.1779, Validation MAPE: 0.4344, Validation RMSE: 0.2186, Training Time: 330.4765/epoch
# Iter: 000, Train Loss: 0.1313, Train MAE: 0.1313, Train MAPE: 0.2576, Train RMSE: 0.1532
# Epoch: 002, Inference Time: 1.8279 secs
# Epoch: 002, Train Loss: 0.1313, Train MAPE: 0.2576, Train RMSE: 0.1532, Validation Loss: 0.1554, Validation MAPE: 0.3786, Validation RMSE: 0.1930, Training Time: 26.7535/epoch
# Epoch: 002, Inference Time: 11.9231 secs
# Epoch: 002, Train Loss: 0.1276, Train MAPE: 0.2377, Train RMSE: 0.1478, Validation Loss: 0.1551, Validation MAPE: 0.3775, Validation RMSE: 0.1912, Training Time: 54.2816/epoch
# Epoch: 002, Inference Time: 1.5131 secs
# Epoch: 002, Train Loss: 0.1285, Train MAPE: 0.2398, Train RMSE: 0.1482, Validation Loss: 0.1696, Validation MAPE: 0.4124, Validation RMSE: 0.2078, Training Time: 103.2213/epoch
# Epoch: 002, Inference Time: 1.7550 secs
# Epoch: 002, Train Loss: 0.1251, Train MAPE: 0.2289, Train RMSE: 0.1445, Validation Loss: 0.1864, Validation MAPE: 0.4532, Validation RMSE: 0.2265, Training Time: 130.8484/epoch
# Epoch: 002, Inference Time: 13.6851 secs
# Epoch: 002, Train Loss: 0.1214, Train MAPE: 0.2238, Train RMSE: 0.1407, Validation Loss: 0.2051, Validation MAPE: 0.4985, Validation RMSE: 0.2480, Training Time: 169.5240/epoch
# Epoch: 002, Inference Time: 1.6151 secs
# Epoch: 002, Train Loss: 0.1185, Train MAPE: 0.2187, Train RMSE: 0.1375, Validation Loss: 0.2207, Validation MAPE: 0.5363, Validation RMSE: 0.2663, Training Time: 217.2375/epoch
# Epoch: 002, Inference Time: 1.4981 secs
# Epoch: 002, Train Loss: 0.1211, Train MAPE: 0.2237, Train RMSE: 0.1405, Validation Loss: 0.2202, Validation MAPE: 0.5352, Validation RMSE: 0.2648, Training Time: 245.0114/epoch
# Epoch: 002, Inference Time: 5.8976 secs
# Epoch: 002, Train Loss: 0.1194, Train MAPE: 0.2261, Train RMSE: 0.1391, Validation Loss: 0.2112, Validation MAPE: 0.5134, Validation RMSE: 0.2524, Training Time: 291.4486/epoch
# Epoch: 002, Inference Time: 2.2197 secs
# Epoch: 002, Train Loss: 0.1163, Train MAPE: 0.2197, Train RMSE: 0.1356, Validation Loss: 0.1926, Validation MAPE: 0.4686, Validation RMSE: 0.2285, Training Time: 326.1015/epoch
# Iter: 000, Train Loss: 0.0942, Train MAE: 0.0942, Train MAPE: 0.1631, Train RMSE: 0.1080
# Epoch: 003, Inference Time: 2.1418 secs
# Epoch: 003, Train Loss: 0.0942, Train MAPE: 0.1631, Train RMSE: 0.1080, Validation Loss: 0.1717, Validation MAPE: 0.4179, Validation RMSE: 0.2016, Training Time: 30.0037/epoch
# Epoch: 003, Inference Time: 2.0348 secs
# Epoch: 003, Train Loss: 0.0929, Train MAPE: 0.1636, Train RMSE: 0.1078, Validation Loss: 0.1605, Validation MAPE: 0.3912, Validation RMSE: 0.1873, Training Time: 99.1657/epoch
# Epoch: 003, Inference Time: 2.1258 secs
# Epoch: 003, Train Loss: 0.0982, Train MAPE: 0.1779, Train RMSE: 0.1144, Validation Loss: 0.1594, Validation MAPE: 0.3889, Validation RMSE: 0.1849, Training Time: 135.4837/epoch
# Epoch: 003, Inference Time: 2.6215 secs
# Epoch: 003, Train Loss: 0.1005, Train MAPE: 0.1876, Train RMSE: 0.1172, Validation Loss: 0.1661, Validation MAPE: 0.4055, Validation RMSE: 0.1932, Training Time: 167.3793/epoch
# Epoch: 003, Inference Time: 1.7460 secs
# Epoch: 003, Train Loss: 0.1046, Train MAPE: 0.2077, Train RMSE: 0.1219, Validation Loss: 0.1796, Validation MAPE: 0.4383, Validation RMSE: 0.2096, Training Time: 224.6862/epoch
# Epoch: 003, Inference Time: 1.6431 secs
# Epoch: 003, Train Loss: 0.1025, Train MAPE: 0.2011, Train RMSE: 0.1195, Validation Loss: 0.1947, Validation MAPE: 0.4753, Validation RMSE: 0.2275, Training Time: 254.6328/epoch
# Epoch: 003, Inference Time: 11.7742 secs
# Epoch: 003, Train Loss: 0.1005, Train MAPE: 0.1970, Train RMSE: 0.1173, Validation Loss: 0.2033, Validation MAPE: 0.4959, Validation RMSE: 0.2380, Training Time: 285.0583/epoch
# Epoch: 003, Inference Time: 1.6890 secs
# Epoch: 003, Train Loss: 0.1021, Train MAPE: 0.2010, Train RMSE: 0.1193, Validation Loss: 0.2036, Validation MAPE: 0.4966, Validation RMSE: 0.2387, Training Time: 338.9851/epoch
# Epoch: 003, Inference Time: 2.0488 secs
# Epoch: 003, Train Loss: 0.1021, Train MAPE: 0.2001, Train RMSE: 0.1194, Validation Loss: 0.1965, Validation MAPE: 0.4792, Validation RMSE: 0.2308, Training Time: 370.8657/epoch
# Iter: 000, Train Loss: 0.0901, Train MAE: 0.0901, Train MAPE: 0.1744, Train RMSE: 0.1055
# Epoch: 004, Inference Time: 16.0502 secs
# Epoch: 004, Train Loss: 0.0901, Train MAPE: 0.1744, Train RMSE: 0.1055, Validation Loss: 0.1863, Validation MAPE: 0.4543, Validation RMSE: 0.2189, Training Time: 38.8920/epoch
# Epoch: 004, Inference Time: 1.6011 secs
# Epoch: 004, Train Loss: 0.0870, Train MAPE: 0.1681, Train RMSE: 0.1021, Validation Loss: 0.1736, Validation MAPE: 0.4235, Validation RMSE: 0.2045, Training Time: 83.5937/epoch
# Epoch: 004, Inference Time: 1.5281 secs
# Epoch: 004, Train Loss: 0.0966, Train MAPE: 0.1854, Train RMSE: 0.1129, Validation Loss: 0.1664, Validation MAPE: 0.4058, Validation RMSE: 0.1962, Training Time: 111.8144/epoch
# Epoch: 004, Inference Time: 5.8826 secs
# Epoch: 004, Train Loss: 0.0957, Train MAPE: 0.1849, Train RMSE: 0.1118, Validation Loss: 0.1668, Validation MAPE: 0.4067, Validation RMSE: 0.1970, Training Time: 158.0507/epoch
# Epoch: 004, Inference Time: 1.4761 secs
# Epoch: 004, Train Loss: 0.0932, Train MAPE: 0.1777, Train RMSE: 0.1094, Validation Loss: 0.1741, Validation MAPE: 0.4246, Validation RMSE: 0.2049, Training Time: 189.7784/epoch
# Epoch: 004, Inference Time: 1.5641 secs
# Epoch: 004, Train Loss: 0.0917, Train MAPE: 0.1742, Train RMSE: 0.1077, Validation Loss: 0.1869, Validation MAPE: 0.4557, Validation RMSE: 0.2193, Training Time: 217.0446/epoch
# Epoch: 004, Inference Time: 1.9279 secs
# Epoch: 004, Train Loss: 0.0904, Train MAPE: 0.1722, Train RMSE: 0.1060, Validation Loss: 0.1978, Validation MAPE: 0.4820, Validation RMSE: 0.2321, Training Time: 271.0274/epoch
# Epoch: 004, Inference Time: 1.4662 secs
# Epoch: 004, Train Loss: 0.0911, Train MAPE: 0.1796, Train RMSE: 0.1071, Validation Loss: 0.2032, Validation MAPE: 0.4948, Validation RMSE: 0.2390, Training Time: 299.2531/epoch
# Epoch: 004, Inference Time: 1.5431 secs
# Epoch: 004, Train Loss: 0.0916, Train MAPE: 0.1812, Train RMSE: 0.1077, Validation Loss: 0.2002, Validation MAPE: 0.4874, Validation RMSE: 0.2362, Training Time: 326.7852/epoch
# Iter: 000, Train Loss: 0.0898, Train MAE: 0.0898, Train MAPE: 0.1625, Train RMSE: 0.1049
# Epoch: 005, Inference Time: 1.4791 secs
# Epoch: 005, Train Loss: 0.0898, Train MAPE: 0.1625, Train RMSE: 0.1049, Validation Loss: 0.1886, Validation MAPE: 0.4592, Validation RMSE: 0.2225, Training Time: 50.2899/epoch
# Epoch: 005, Inference Time: 1.7910 secs
# Epoch: 005, Train Loss: 0.0861, Train MAPE: 0.1598, Train RMSE: 0.1002, Validation Loss: 0.1734, Validation MAPE: 0.4224, Validation RMSE: 0.2045, Training Time: 77.7351/epoch
# Epoch: 005, Inference Time: 12.2629 secs
# Epoch: 005, Train Loss: 0.0831, Train MAPE: 0.1526, Train RMSE: 0.0973, Validation Loss: 0.1664, Validation MAPE: 0.4055, Validation RMSE: 0.1968, Training Time: 105.2971/epoch
# Epoch: 005, Inference Time: 1.4692 secs
# Epoch: 005, Train Loss: 0.0803, Train MAPE: 0.1464, Train RMSE: 0.0937, Validation Loss: 0.1672, Validation MAPE: 0.4076, Validation RMSE: 0.1985, Training Time: 152.5049/epoch
# Epoch: 005, Inference Time: 1.7590 secs
# Epoch: 005, Train Loss: 0.0834, Train MAPE: 0.1575, Train RMSE: 0.0976, Validation Loss: 0.1766, Validation MAPE: 0.4304, Validation RMSE: 0.2098, Training Time: 179.5832/epoch
# Epoch: 005, Inference Time: 11.2945 secs
# Epoch: 005, Train Loss: 0.0846, Train MAPE: 0.1612, Train RMSE: 0.0990, Validation Loss: 0.1861, Validation MAPE: 0.4535, Validation RMSE: 0.2210, Training Time: 217.5513/epoch
# Epoch: 005, Inference Time: 1.6850 secs
# Epoch: 005, Train Loss: 0.0853, Train MAPE: 0.1640, Train RMSE: 0.0999, Validation Loss: 0.1955, Validation MAPE: 0.4767, Validation RMSE: 0.2314, Training Time: 256.6337/epoch
# Epoch: 005, Inference Time: 1.5361 secs
# Epoch: 005, Train Loss: 0.0864, Train MAPE: 0.1664, Train RMSE: 0.1014, Validation Loss: 0.2023, Validation MAPE: 0.4934, Validation RMSE: 0.2385, Training Time: 283.6161/epoch
# Epoch: 005, Inference Time: 5.3829 secs
# Epoch: 005, Train Loss: 0.0885, Train MAPE: 0.1777, Train RMSE: 0.1040, Validation Loss: 0.2045, Validation MAPE: 0.4986, Validation RMSE: 0.2407, Training Time: 332.5788/epoch
# Iter: 000, Train Loss: 0.0692, Train MAE: 0.0692, Train MAPE: 0.1271, Train RMSE: 0.0820
# Epoch: 006, Inference Time: 1.5131 secs
# Epoch: 006, Train Loss: 0.0692, Train MAPE: 0.1271, Train RMSE: 0.0820, Validation Loss: 0.1962, Validation MAPE: 0.4784, Validation RMSE: 0.2305, Training Time: 25.7371/epoch
# Epoch: 006, Inference Time: 1.6361 secs
# Epoch: 006, Train Loss: 0.0706, Train MAPE: 0.1299, Train RMSE: 0.0830, Validation Loss: 0.1786, Validation MAPE: 0.4358, Validation RMSE: 0.2097, Training Time: 53.3682/epoch
# Epoch: 006, Inference Time: 1.4841 secs
# Epoch: 006, Train Loss: 0.0807, Train MAPE: 0.1503, Train RMSE: 0.0949, Validation Loss: 0.1650, Validation MAPE: 0.4029, Validation RMSE: 0.1936, Training Time: 105.3231/epoch
# Epoch: 006, Inference Time: 1.8080 secs
# Epoch: 006, Train Loss: 0.0798, Train MAPE: 0.1467, Train RMSE: 0.0940, Validation Loss: 0.1605, Validation MAPE: 0.3918, Validation RMSE: 0.1883, Training Time: 133.7657/epoch
# Epoch: 006, Inference Time: 2.1687 secs
# Epoch: 006, Train Loss: 0.0834, Train MAPE: 0.1624, Train RMSE: 0.0985, Validation Loss: 0.1647, Validation MAPE: 0.4023, Validation RMSE: 0.1936, Training Time: 160.8241/epoch
# Epoch: 006, Inference Time: 1.6271 secs
# Epoch: 006, Train Loss: 0.0863, Train MAPE: 0.1697, Train RMSE: 0.1017, Validation Loss: 0.1807, Validation MAPE: 0.4412, Validation RMSE: 0.2116, Training Time: 211.8456/epoch
# Epoch: 006, Inference Time: 1.6351 secs
# Epoch: 006, Train Loss: 0.0859, Train MAPE: 0.1686, Train RMSE: 0.1011, Validation Loss: 0.1988, Validation MAPE: 0.4850, Validation RMSE: 0.2315, Training Time: 238.9459/epoch
# Epoch: 006, Inference Time: 12.0330 secs
# Epoch: 006, Train Loss: 0.0863, Train MAPE: 0.1689, Train RMSE: 0.1017, Validation Loss: 0.2123, Validation MAPE: 0.5180, Validation RMSE: 0.2469, Training Time: 267.0587/epoch
# Epoch: 006, Inference Time: 1.5371 secs
# Epoch: 006, Train Loss: 0.0861, Train MAPE: 0.1695, Train RMSE: 0.1016, Validation Loss: 0.2180, Validation MAPE: 0.5318, Validation RMSE: 0.2536, Training Time: 313.8686/epoch
# Iter: 000, Train Loss: 0.0872, Train MAE: 0.0872, Train MAPE: 0.1837, Train RMSE: 0.1033
# Epoch: 007, Inference Time: 1.6900 secs
# Epoch: 007, Train Loss: 0.0872, Train MAPE: 0.1837, Train RMSE: 0.1033, Validation Loss: 0.2081, Validation MAPE: 0.5075, Validation RMSE: 0.2426, Training Time: 26.9364/epoch
# Epoch: 007, Inference Time: 1.2733 secs
# Epoch: 007, Train Loss: 0.0872, Train MAPE: 0.1821, Train RMSE: 0.1031, Validation Loss: 0.1925, Validation MAPE: 0.4695, Validation RMSE: 0.2255, Training Time: 53.8919/epoch
# Epoch: 007, Inference Time: 1.3272 secs
# Epoch: 007, Train Loss: 0.0924, Train MAPE: 0.2033, Train RMSE: 0.1087, Validation Loss: 0.1792, Validation MAPE: 0.4371, Validation RMSE: 0.2109, Training Time: 79.8888/epoch
# Epoch: 007, Inference Time: 1.3752 secs
# Epoch: 007, Train Loss: 0.0880, Train MAPE: 0.1868, Train RMSE: 0.1036, Validation Loss: 0.1734, Validation MAPE: 0.4227, Validation RMSE: 0.2047, Training Time: 105.8498/epoch
# Epoch: 007, Inference Time: 1.3732 secs
# Epoch: 007, Train Loss: 0.0869, Train MAPE: 0.1812, Train RMSE: 0.1023, Validation Loss: 0.1789, Validation MAPE: 0.4360, Validation RMSE: 0.2115, Training Time: 131.6479/epoch
# Epoch: 007, Inference Time: 1.4312 secs
# Epoch: 007, Train Loss: 0.0848, Train MAPE: 0.1726, Train RMSE: 0.0998, Validation Loss: 0.1870, Validation MAPE: 0.4559, Validation RMSE: 0.2208, Training Time: 160.5672/epoch
# Epoch: 007, Inference Time: 1.2063 secs
# Epoch: 007, Train Loss: 0.0845, Train MAPE: 0.1720, Train RMSE: 0.0997, Validation Loss: 0.1956, Validation MAPE: 0.4769, Validation RMSE: 0.2302, Training Time: 187.5626/epoch
# Epoch: 007, Inference Time: 1.2173 secs
# Epoch: 007, Train Loss: 0.0835, Train MAPE: 0.1685, Train RMSE: 0.0984, Validation Loss: 0.2025, Validation MAPE: 0.4936, Validation RMSE: 0.2372, Training Time: 213.6036/epoch
# Epoch: 007, Inference Time: 1.2273 secs
# Epoch: 007, Train Loss: 0.0845, Train MAPE: 0.1691, Train RMSE: 0.0996, Validation Loss: 0.2028, Validation MAPE: 0.4944, Validation RMSE: 0.2367, Training Time: 240.5330/epoch
# Iter: 000, Train Loss: 0.0730, Train MAE: 0.0730, Train MAPE: 0.1445, Train RMSE: 0.0862
# Epoch: 008, Inference Time: 1.3752 secs
# Epoch: 008, Train Loss: 0.0730, Train MAPE: 0.1445, Train RMSE: 0.0862, Validation Loss: 0.1971, Validation MAPE: 0.4805, Validation RMSE: 0.2299, Training Time: 25.5832/epoch
# Epoch: 008, Inference Time: 1.2533 secs
# Epoch: 008, Train Loss: 0.0816, Train MAPE: 0.1626, Train RMSE: 0.0961, Validation Loss: 0.1889, Validation MAPE: 0.4606, Validation RMSE: 0.2207, Training Time: 51.6611/epoch
# Epoch: 008, Inference Time: 1.2513 secs
# Epoch: 008, Train Loss: 0.0760, Train MAPE: 0.1495, Train RMSE: 0.0896, Validation Loss: 0.1801, Validation MAPE: 0.4393, Validation RMSE: 0.2113, Training Time: 77.5562/epoch
# Epoch: 008, Inference Time: 1.4302 secs
# Epoch: 008, Train Loss: 0.0771, Train MAPE: 0.1501, Train RMSE: 0.0910, Validation Loss: 0.1718, Validation MAPE: 0.4192, Validation RMSE: 0.2029, Training Time: 103.9799/epoch
# Epoch: 008, Inference Time: 1.3602 secs
# Epoch: 008, Train Loss: 0.0831, Train MAPE: 0.1735, Train RMSE: 0.0980, Validation Loss: 0.1731, Validation MAPE: 0.4224, Validation RMSE: 0.2055, Training Time: 128.9495/epoch
# Epoch: 008, Inference Time: 1.5641 secs
# Epoch: 008, Train Loss: 0.0822, Train MAPE: 0.1686, Train RMSE: 0.0975, Validation Loss: 0.1801, Validation MAPE: 0.4394, Validation RMSE: 0.2148, Training Time: 154.4058/epoch
# Epoch: 008, Inference Time: 1.3432 secs
# Epoch: 008, Train Loss: 0.0801, Train MAPE: 0.1616, Train RMSE: 0.0950, Validation Loss: 0.1836, Validation MAPE: 0.4479, Validation RMSE: 0.2188, Training Time: 179.7631/epoch
# Epoch: 008, Inference Time: 1.3912 secs
# Epoch: 008, Train Loss: 0.0799, Train MAPE: 0.1609, Train RMSE: 0.0946, Validation Loss: 0.1858, Validation MAPE: 0.4535, Validation RMSE: 0.2207, Training Time: 205.2984/epoch
# Epoch: 008, Inference Time: 1.3632 secs
# Epoch: 008, Train Loss: 0.0809, Train MAPE: 0.1629, Train RMSE: 0.0961, Validation Loss: 0.1853, Validation MAPE: 0.4524, Validation RMSE: 0.2190, Training Time: 230.9875/epoch
# Iter: 000, Train Loss: 0.0697, Train MAE: 0.0697, Train MAPE: 0.1447, Train RMSE: 0.0828
# Epoch: 009, Inference Time: 1.3122 secs
# Epoch: 009, Train Loss: 0.0697, Train MAPE: 0.1447, Train RMSE: 0.0828, Validation Loss: 0.1867, Validation MAPE: 0.4558, Validation RMSE: 0.2199, Training Time: 24.5258/epoch
# Epoch: 009, Inference Time: 1.3012 secs
# Epoch: 009, Train Loss: 0.0755, Train MAPE: 0.1515, Train RMSE: 0.0909, Validation Loss: 0.1887, Validation MAPE: 0.4608, Validation RMSE: 0.2213, Training Time: 50.5788/epoch
# Epoch: 009, Inference Time: 1.3862 secs
# Epoch: 009, Train Loss: 0.0776, Train MAPE: 0.1616, Train RMSE: 0.0928, Validation Loss: 0.1916, Validation MAPE: 0.4677, Validation RMSE: 0.2238, Training Time: 76.3179/epoch
# Epoch: 009, Inference Time: 1.4112 secs
# Epoch: 009, Train Loss: 0.0766, Train MAPE: 0.1557, Train RMSE: 0.0915, Validation Loss: 0.1958, Validation MAPE: 0.4779, Validation RMSE: 0.2284, Training Time: 102.0130/epoch
# Epoch: 009, Inference Time: 1.2383 secs
# Epoch: 009, Train Loss: 0.0756, Train MAPE: 0.1520, Train RMSE: 0.0900, Validation Loss: 0.1936, Validation MAPE: 0.4725, Validation RMSE: 0.2258, Training Time: 129.0554/epoch
# Epoch: 009, Inference Time: 1.5441 secs
# Epoch: 009, Train Loss: 0.0773, Train MAPE: 0.1552, Train RMSE: 0.0920, Validation Loss: 0.1884, Validation MAPE: 0.4598, Validation RMSE: 0.2201, Training Time: 154.1299/epoch
# Epoch: 009, Inference Time: 1.5541 secs
# Epoch: 009, Train Loss: 0.0762, Train MAPE: 0.1525, Train RMSE: 0.0907, Validation Loss: 0.1827, Validation MAPE: 0.4459, Validation RMSE: 0.2137, Training Time: 179.6742/epoch
# Epoch: 009, Inference Time: 1.2972 secs
# Epoch: 009, Train Loss: 0.0761, Train MAPE: 0.1562, Train RMSE: 0.0909, Validation Loss: 0.1816, Validation MAPE: 0.4431, Validation RMSE: 0.2125, Training Time: 205.3753/epoch
# Epoch: 009, Inference Time: 1.3002 secs
# Epoch: 009, Train Loss: 0.0775, Train MAPE: 0.1583, Train RMSE: 0.0922, Validation Loss: 0.1843, Validation MAPE: 0.4498, Validation RMSE: 0.2155, Training Time: 231.4073/epoch
# Iter: 000, Train Loss: 0.0626, Train MAE: 0.0626, Train MAPE: 0.1179, Train RMSE: 0.0743
# Epoch: 010, Inference Time: 1.3802 secs
# Epoch: 010, Train Loss: 0.0626, Train MAPE: 0.1179, Train RMSE: 0.0743, Validation Loss: 0.1869, Validation MAPE: 0.4559, Validation RMSE: 0.2183, Training Time: 24.4669/epoch
# Epoch: 010, Inference Time: 1.3192 secs
# Epoch: 010, Train Loss: 0.0754, Train MAPE: 0.1545, Train RMSE: 0.0896, Validation Loss: 0.1970, Validation MAPE: 0.4804, Validation RMSE: 0.2297, Training Time: 50.4399/epoch
# Epoch: 010, Inference Time: 1.3972 secs
# Epoch: 010, Train Loss: 0.0768, Train MAPE: 0.1555, Train RMSE: 0.0910, Validation Loss: 0.2010, Validation MAPE: 0.4900, Validation RMSE: 0.2343, Training Time: 76.0660/epoch
# Epoch: 010, Inference Time: 1.3472 secs
# Epoch: 010, Train Loss: 0.0789, Train MAPE: 0.1569, Train RMSE: 0.0940, Validation Loss: 0.1970, Validation MAPE: 0.4803, Validation RMSE: 0.2296, Training Time: 102.0340/epoch
# Epoch: 010, Inference Time: 1.4022 secs
# Epoch: 010, Train Loss: 0.0791, Train MAPE: 0.1578, Train RMSE: 0.0945, Validation Loss: 0.1944, Validation MAPE: 0.4741, Validation RMSE: 0.2265, Training Time: 128.1270/epoch
# Epoch: 010, Inference Time: 1.3902 secs
# Epoch: 010, Train Loss: 0.0797, Train MAPE: 0.1584, Train RMSE: 0.0947, Validation Loss: 0.1927, Validation MAPE: 0.4700, Validation RMSE: 0.2245, Training Time: 154.7026/epoch
# Epoch: 010, Inference Time: 1.3312 secs
# Epoch: 010, Train Loss: 0.0776, Train MAPE: 0.1529, Train RMSE: 0.0921, Validation Loss: 0.1880, Validation MAPE: 0.4587, Validation RMSE: 0.2192, Training Time: 180.5227/epoch
# Epoch: 010, Inference Time: 1.3422 secs
# Epoch: 010, Train Loss: 0.0768, Train MAPE: 0.1498, Train RMSE: 0.0912, Validation Loss: 0.1841, Validation MAPE: 0.4494, Validation RMSE: 0.2150, Training Time: 207.1843/epoch
# Epoch: 010, Inference Time: 1.1963 secs
# Epoch: 010, Train Loss: 0.0786, Train MAPE: 0.1580, Train RMSE: 0.0931, Validation Loss: 0.1849, Validation MAPE: 0.4515, Validation RMSE: 0.2162, Training Time: 233.5230/epoch
# Iter: 000, Train Loss: 0.0785, Train MAE: 0.0785, Train MAPE: 0.1561, Train RMSE: 0.0935
# Epoch: 011, Inference Time: 1.2063 secs
# Epoch: 011, Train Loss: 0.0785, Train MAPE: 0.1561, Train RMSE: 0.0935, Validation Loss: 0.1900, Validation MAPE: 0.4638, Validation RMSE: 0.2220, Training Time: 24.0731/epoch
# Epoch: 011, Inference Time: 1.1963 secs
# Epoch: 011, Train Loss: 0.0736, Train MAPE: 0.1460, Train RMSE: 0.0871, Validation Loss: 0.1962, Validation MAPE: 0.4790, Validation RMSE: 0.2293, Training Time: 49.7732/epoch
# Epoch: 011, Inference Time: 1.2083 secs
# Epoch: 011, Train Loss: 0.0708, Train MAPE: 0.1380, Train RMSE: 0.0838, Validation Loss: 0.1957, Validation MAPE: 0.4777, Validation RMSE: 0.2291, Training Time: 74.8797/epoch
# Epoch: 011, Inference Time: 1.2083 secs
# Epoch: 011, Train Loss: 0.0727, Train MAPE: 0.1429, Train RMSE: 0.0859, Validation Loss: 0.1903, Validation MAPE: 0.4646, Validation RMSE: 0.2238, Training Time: 100.2751/epoch
# Epoch: 011, Inference Time: 1.2523 secs
# Epoch: 011, Train Loss: 0.0719, Train MAPE: 0.1391, Train RMSE: 0.0855, Validation Loss: 0.1859, Validation MAPE: 0.4540, Validation RMSE: 0.2189, Training Time: 125.6174/epoch
# Epoch: 011, Inference Time: 1.3192 secs
# Epoch: 011, Train Loss: 0.0733, Train MAPE: 0.1437, Train RMSE: 0.0870, Validation Loss: 0.1842, Validation MAPE: 0.4501, Validation RMSE: 0.2168, Training Time: 150.8608/epoch
# Epoch: 011, Inference Time: 1.3722 secs
# Epoch: 011, Train Loss: 0.0763, Train MAPE: 0.1595, Train RMSE: 0.0906, Validation Loss: 0.1911, Validation MAPE: 0.4669, Validation RMSE: 0.2245, Training Time: 176.5900/epoch
# Epoch: 011, Inference Time: 1.4771 secs
# Epoch: 011, Train Loss: 0.0746, Train MAPE: 0.1551, Train RMSE: 0.0885, Validation Loss: 0.1947, Validation MAPE: 0.4757, Validation RMSE: 0.2285, Training Time: 201.9463/epoch
# Epoch: 011, Inference Time: 1.3192 secs
# Epoch: 011, Train Loss: 0.0767, Train MAPE: 0.1578, Train RMSE: 0.0910, Validation Loss: 0.1977, Validation MAPE: 0.4828, Validation RMSE: 0.2315, Training Time: 228.3291/epoch
# Iter: 000, Train Loss: 0.0680, Train MAE: 0.0680, Train MAPE: 0.1216, Train RMSE: 0.0803
# Epoch: 012, Inference Time: 1.2763 secs
# Epoch: 012, Train Loss: 0.0680, Train MAPE: 0.1216, Train RMSE: 0.0803, Validation Loss: 0.1905, Validation MAPE: 0.4651, Validation RMSE: 0.2231, Training Time: 24.3209/epoch
# Epoch: 012, Inference Time: 1.4741 secs
# Epoch: 012, Train Loss: 0.0650, Train MAPE: 0.1225, Train RMSE: 0.0768, Validation Loss: 0.1833, Validation MAPE: 0.4476, Validation RMSE: 0.2148, Training Time: 49.5374/epoch
# Epoch: 012, Inference Time: 1.3782 secs
# Epoch: 012, Train Loss: 0.0704, Train MAPE: 0.1405, Train RMSE: 0.0837, Validation Loss: 0.1827, Validation MAPE: 0.4460, Validation RMSE: 0.2139, Training Time: 75.7132/epoch
# Epoch: 012, Inference Time: 1.3882 secs
# Epoch: 012, Train Loss: 0.0727, Train MAPE: 0.1461, Train RMSE: 0.0864, Validation Loss: 0.1858, Validation MAPE: 0.4535, Validation RMSE: 0.2172, Training Time: 101.3434/epoch
# Epoch: 012, Inference Time: 1.3642 secs
# Epoch: 012, Train Loss: 0.0733, Train MAPE: 0.1464, Train RMSE: 0.0872, Validation Loss: 0.1923, Validation MAPE: 0.4694, Validation RMSE: 0.2242, Training Time: 126.9276/epoch
# Epoch: 012, Inference Time: 1.2863 secs
# Epoch: 012, Train Loss: 0.0722, Train MAPE: 0.1435, Train RMSE: 0.0856, Validation Loss: 0.1972, Validation MAPE: 0.4815, Validation RMSE: 0.2299, Training Time: 153.1485/epoch
# Epoch: 012, Inference Time: 1.2593 secs
# Epoch: 012, Train Loss: 0.0712, Train MAPE: 0.1407, Train RMSE: 0.0844, Validation Loss: 0.1937, Validation MAPE: 0.4729, Validation RMSE: 0.2264, Training Time: 179.5063/epoch
# Epoch: 012, Inference Time: 1.3402 secs
# Epoch: 012, Train Loss: 0.0718, Train MAPE: 0.1418, Train RMSE: 0.0851, Validation Loss: 0.1857, Validation MAPE: 0.4533, Validation RMSE: 0.2179, Training Time: 205.1045/epoch
# Epoch: 012, Inference Time: 1.3592 secs
# Epoch: 012, Train Loss: 0.0764, Train MAPE: 0.1566, Train RMSE: 0.0903, Validation Loss: 0.1851, Validation MAPE: 0.4516, Validation RMSE: 0.2174, Training Time: 230.4338/epoch
# Iter: 000, Train Loss: 0.0855, Train MAE: 0.0855, Train MAPE: 0.1769, Train RMSE: 0.0998
# Epoch: 013, Inference Time: 1.3142 secs
# Epoch: 013, Train Loss: 0.0855, Train MAPE: 0.1769, Train RMSE: 0.0998, Validation Loss: 0.1889, Validation MAPE: 0.4610, Validation RMSE: 0.2220, Training Time: 24.0451/epoch
# Epoch: 013, Inference Time: 1.3392 secs
# Epoch: 013, Train Loss: 0.0840, Train MAPE: 0.1628, Train RMSE: 0.0992, Validation Loss: 0.1920, Validation MAPE: 0.4685, Validation RMSE: 0.2255, Training Time: 49.8732/epoch
# Epoch: 013, Inference Time: 1.2193 secs
# Epoch: 013, Train Loss: 0.0808, Train MAPE: 0.1550, Train RMSE: 0.0957, Validation Loss: 0.1940, Validation MAPE: 0.4734, Validation RMSE: 0.2276, Training Time: 76.8806/epoch
# Epoch: 013, Inference Time: 1.2433 secs
# Epoch: 013, Train Loss: 0.0784, Train MAPE: 0.1524, Train RMSE: 0.0936, Validation Loss: 0.1971, Validation MAPE: 0.4811, Validation RMSE: 0.2310, Training Time: 101.9731/epoch
# Epoch: 013, Inference Time: 1.2673 secs
# Epoch: 013, Train Loss: 0.0791, Train MAPE: 0.1643, Train RMSE: 0.0942, Validation Loss: 0.1985, Validation MAPE: 0.4845, Validation RMSE: 0.2322, Training Time: 127.4344/epoch
# Epoch: 013, Inference Time: 1.4352 secs
# Epoch: 013, Train Loss: 0.0760, Train MAPE: 0.1558, Train RMSE: 0.0903, Validation Loss: 0.1940, Validation MAPE: 0.4735, Validation RMSE: 0.2271, Training Time: 152.8627/epoch
# Epoch: 013, Inference Time: 1.5211 secs
# Epoch: 013, Train Loss: 0.0751, Train MAPE: 0.1546, Train RMSE: 0.0895, Validation Loss: 0.1877, Validation MAPE: 0.4583, Validation RMSE: 0.2205, Training Time: 178.7297/epoch
# Epoch: 013, Inference Time: 1.4122 secs
# Epoch: 013, Train Loss: 0.0760, Train MAPE: 0.1565, Train RMSE: 0.0904, Validation Loss: 0.1829, Validation MAPE: 0.4465, Validation RMSE: 0.2159, Training Time: 204.7427/epoch
# Epoch: 013, Inference Time: 1.6111 secs
# Epoch: 013, Train Loss: 0.0757, Train MAPE: 0.1557, Train RMSE: 0.0902, Validation Loss: 0.1845, Validation MAPE: 0.4503, Validation RMSE: 0.2178, Training Time: 230.1680/epoch
# Iter: 000, Train Loss: 0.0823, Train MAE: 0.0823, Train MAPE: 0.2036, Train RMSE: 0.0985
# Epoch: 014, Inference Time: 1.5321 secs
# Epoch: 014, Train Loss: 0.0823, Train MAPE: 0.2036, Train RMSE: 0.0985, Validation Loss: 0.1934, Validation MAPE: 0.4718, Validation RMSE: 0.2276, Training Time: 25.0035/epoch
# Epoch: 014, Inference Time: 1.4961 secs
# Epoch: 014, Train Loss: 0.0817, Train MAPE: 0.1766, Train RMSE: 0.0985, Validation Loss: 0.1953, Validation MAPE: 0.4765, Validation RMSE: 0.2291, Training Time: 51.3493/epoch
# Epoch: 014, Inference Time: 1.4302 secs
# Epoch: 014, Train Loss: 0.0775, Train MAPE: 0.1598, Train RMSE: 0.0929, Validation Loss: 0.1952, Validation MAPE: 0.4764, Validation RMSE: 0.2283, Training Time: 77.2484/epoch
# Epoch: 014, Inference Time: 1.3362 secs
# Epoch: 014, Train Loss: 0.0741, Train MAPE: 0.1499, Train RMSE: 0.0884, Validation Loss: 0.1945, Validation MAPE: 0.4746, Validation RMSE: 0.2270, Training Time: 103.0445/epoch
# Epoch: 014, Inference Time: 1.3192 secs
# Epoch: 014, Train Loss: 0.0726, Train MAPE: 0.1478, Train RMSE: 0.0863, Validation Loss: 0.1949, Validation MAPE: 0.4757, Validation RMSE: 0.2275, Training Time: 128.2939/epoch
# Epoch: 014, Inference Time: 1.3582 secs
# Epoch: 014, Train Loss: 0.0745, Train MAPE: 0.1514, Train RMSE: 0.0887, Validation Loss: 0.1969, Validation MAPE: 0.4805, Validation RMSE: 0.2300, Training Time: 153.6722/epoch
# Epoch: 014, Inference Time: 1.4152 secs
# Epoch: 014, Train Loss: 0.0724, Train MAPE: 0.1466, Train RMSE: 0.0862, Validation Loss: 0.1926, Validation MAPE: 0.4700, Validation RMSE: 0.2252, Training Time: 179.3544/epoch
# Epoch: 014, Inference Time: 1.4462 secs
# Epoch: 014, Train Loss: 0.0717, Train MAPE: 0.1442, Train RMSE: 0.0855, Validation Loss: 0.1860, Validation MAPE: 0.4540, Validation RMSE: 0.2178, Training Time: 205.1764/epoch
# Epoch: 014, Inference Time: 1.3562 secs
# Epoch: 014, Train Loss: 0.0746, Train MAPE: 0.1525, Train RMSE: 0.0886, Validation Loss: 0.1900, Validation MAPE: 0.4638, Validation RMSE: 0.2225, Training Time: 230.9785/epoch
# Iter: 000, Train Loss: 0.0958, Train MAE: 0.0958, Train MAPE: 0.2168, Train RMSE: 0.1117
# Epoch: 015, Inference Time: 1.3902 secs
# Epoch: 015, Train Loss: 0.0958, Train MAPE: 0.2168, Train RMSE: 0.1117, Validation Loss: 0.2003, Validation MAPE: 0.4888, Validation RMSE: 0.2343, Training Time: 25.3094/epoch
# Epoch: 015, Inference Time: 1.3132 secs
# Epoch: 015, Train Loss: 0.0852, Train MAPE: 0.1866, Train RMSE: 0.1000, Validation Loss: 0.2034, Validation MAPE: 0.4959, Validation RMSE: 0.2379, Training Time: 51.7801/epoch
# Epoch: 015, Inference Time: 1.3452 secs
# Epoch: 015, Train Loss: 0.0760, Train MAPE: 0.1599, Train RMSE: 0.0891, Validation Loss: 0.1943, Validation MAPE: 0.4736, Validation RMSE: 0.2278, Training Time: 77.2304/epoch
# Epoch: 015, Inference Time: 1.4272 secs
# Epoch: 015, Train Loss: 0.0742, Train MAPE: 0.1510, Train RMSE: 0.0869, Validation Loss: 0.1831, Validation MAPE: 0.4463, Validation RMSE: 0.2152, Training Time: 103.6351/epoch
# Epoch: 015, Inference Time: 1.2353 secs
# Epoch: 015, Train Loss: 0.0772, Train MAPE: 0.1564, Train RMSE: 0.0907, Validation Loss: 0.1783, Validation MAPE: 0.4346, Validation RMSE: 0.2098, Training Time: 129.6081/epoch
# Epoch: 015, Inference Time: 1.3352 secs
# Epoch: 015, Train Loss: 0.0777, Train MAPE: 0.1546, Train RMSE: 0.0917, Validation Loss: 0.1857, Validation MAPE: 0.4526, Validation RMSE: 0.2181, Training Time: 154.7876/epoch
# Epoch: 015, Inference Time: 1.1943 secs
# Epoch: 015, Train Loss: 0.0781, Train MAPE: 0.1608, Train RMSE: 0.0923, Validation Loss: 0.1993, Validation MAPE: 0.4859, Validation RMSE: 0.2334, Training Time: 181.2153/epoch
# Epoch: 015, Inference Time: 1.2393 secs
# Epoch: 015, Train Loss: 0.0767, Train MAPE: 0.1564, Train RMSE: 0.0905, Validation Loss: 0.2026, Validation MAPE: 0.4941, Validation RMSE: 0.2370, Training Time: 206.6426/epoch
# Epoch: 015, Inference Time: 1.1933 secs
# Epoch: 015, Train Loss: 0.0752, Train MAPE: 0.1530, Train RMSE: 0.0888, Validation Loss: 0.1940, Validation MAPE: 0.4733, Validation RMSE: 0.2270, Training Time: 232.5106/epoch
# Iter: 000, Train Loss: 0.0890, Train MAE: 0.0890, Train MAPE: 0.1673, Train RMSE: 0.1083
# Epoch: 016, Inference Time: 1.2443 secs
# Epoch: 016, Train Loss: 0.0890, Train MAPE: 0.1673, Train RMSE: 0.1083, Validation Loss: 0.1808, Validation MAPE: 0.4416, Validation RMSE: 0.2120, Training Time: 24.5888/epoch
# Epoch: 016, Inference Time: 1.1883 secs
# Epoch: 016, Train Loss: 0.0846, Train MAPE: 0.1702, Train RMSE: 0.1027, Validation Loss: 0.1786, Validation MAPE: 0.4363, Validation RMSE: 0.2090, Training Time: 49.7722/epoch
# Epoch: 016, Inference Time: 1.2153 secs
# Epoch: 016, Train Loss: 0.0866, Train MAPE: 0.1895, Train RMSE: 0.1041, Validation Loss: 0.1878, Validation MAPE: 0.4590, Validation RMSE: 0.2189, Training Time: 75.8672/epoch
# Epoch: 016, Inference Time: 1.3582 secs
# Epoch: 016, Train Loss: 0.0822, Train MAPE: 0.1769, Train RMSE: 0.0992, Validation Loss: 0.2009, Validation MAPE: 0.4911, Validation RMSE: 0.2328, Training Time: 101.5863/epoch
# Epoch: 016, Inference Time: 1.2043 secs
# Epoch: 016, Train Loss: 0.0800, Train MAPE: 0.1686, Train RMSE: 0.0962, Validation Loss: 0.2021, Validation MAPE: 0.4940, Validation RMSE: 0.2341, Training Time: 127.2045/epoch
# Epoch: 016, Inference Time: 1.2393 secs
# Epoch: 016, Train Loss: 0.0793, Train MAPE: 0.1649, Train RMSE: 0.0951, Validation Loss: 0.1878, Validation MAPE: 0.4589, Validation RMSE: 0.2191, Training Time: 153.2824/epoch
# Epoch: 016, Inference Time: 1.1933 secs
# Epoch: 016, Train Loss: 0.0775, Train MAPE: 0.1588, Train RMSE: 0.0928, Validation Loss: 0.1750, Validation MAPE: 0.4277, Validation RMSE: 0.2055, Training Time: 179.3913/epoch
# Epoch: 016, Inference Time: 1.2323 secs
# Epoch: 016, Train Loss: 0.0754, Train MAPE: 0.1530, Train RMSE: 0.0900, Validation Loss: 0.1731, Validation MAPE: 0.4229, Validation RMSE: 0.2038, Training Time: 205.0665/epoch
# Epoch: 016, Inference Time: 1.2553 secs
# Epoch: 016, Train Loss: 0.0758, Train MAPE: 0.1546, Train RMSE: 0.0906, Validation Loss: 0.1848, Validation MAPE: 0.4513, Validation RMSE: 0.2172, Training Time: 231.1104/epoch
# Iter: 000, Train Loss: 0.0649, Train MAE: 0.0649, Train MAPE: 0.1259, Train RMSE: 0.0759
# Epoch: 017, Inference Time: 1.3782 secs
# Epoch: 017, Train Loss: 0.0649, Train MAPE: 0.1259, Train RMSE: 0.0759, Validation Loss: 0.1998, Validation MAPE: 0.4877, Validation RMSE: 0.2339, Training Time: 24.8826/epoch
# Epoch: 017, Inference Time: 1.3562 secs
# Epoch: 017, Train Loss: 0.0681, Train MAPE: 0.1333, Train RMSE: 0.0820, Validation Loss: 0.2071, Validation MAPE: 0.5054, Validation RMSE: 0.2419, Training Time: 51.0495/epoch
# Epoch: 017, Inference Time: 1.2833 secs
# Epoch: 017, Train Loss: 0.0759, Train MAPE: 0.1745, Train RMSE: 0.0912, Validation Loss: 0.2101, Validation MAPE: 0.5125, Validation RMSE: 0.2459, Training Time: 76.6707/epoch
# Epoch: 017, Inference Time: 1.2503 secs
# Epoch: 017, Train Loss: 0.0782, Train MAPE: 0.1695, Train RMSE: 0.0937, Validation Loss: 0.1967, Validation MAPE: 0.4800, Validation RMSE: 0.2311, Training Time: 102.6957/epoch
# Epoch: 017, Inference Time: 1.2393 secs
# Epoch: 017, Train Loss: 0.0759, Train MAPE: 0.1617, Train RMSE: 0.0907, Validation Loss: 0.1785, Validation MAPE: 0.4357, Validation RMSE: 0.2110, Training Time: 128.6866/epoch
# Epoch: 017, Inference Time: 1.5171 secs
# Epoch: 017, Train Loss: 0.0764, Train MAPE: 0.1618, Train RMSE: 0.0910, Validation Loss: 0.1734, Validation MAPE: 0.4231, Validation RMSE: 0.2049, Training Time: 153.9171/epoch
# Epoch: 017, Inference Time: 1.3702 secs
# Epoch: 017, Train Loss: 0.0745, Train MAPE: 0.1545, Train RMSE: 0.0886, Validation Loss: 0.1790, Validation MAPE: 0.4369, Validation RMSE: 0.2105, Training Time: 180.0859/epoch
# Epoch: 017, Inference Time: 1.3802 secs
# Epoch: 017, Train Loss: 0.0744, Train MAPE: 0.1530, Train RMSE: 0.0884, Validation Loss: 0.1935, Validation MAPE: 0.4722, Validation RMSE: 0.2260, Training Time: 205.7341/epoch
# Epoch: 017, Inference Time: 1.3412 secs
# Epoch: 017, Train Loss: 0.0740, Train MAPE: 0.1514, Train RMSE: 0.0878, Validation Loss: 0.2105, Validation MAPE: 0.5135, Validation RMSE: 0.2448, Training Time: 231.7721/epoch
# Iter: 000, Train Loss: 0.0799, Train MAE: 0.0799, Train MAPE: 0.2097, Train RMSE: 0.0965
# Epoch: 018, Inference Time: 1.4122 secs
# Epoch: 018, Train Loss: 0.0799, Train MAPE: 0.2097, Train RMSE: 0.0965, Validation Loss: 0.2123, Validation MAPE: 0.5179, Validation RMSE: 0.2471, Training Time: 24.7957/epoch
# Epoch: 018, Inference Time: 1.3382 secs
# Epoch: 018, Train Loss: 0.0744, Train MAPE: 0.1740, Train RMSE: 0.0894, Validation Loss: 0.1985, Validation MAPE: 0.4843, Validation RMSE: 0.2323, Training Time: 50.7727/epoch
# Epoch: 018, Inference Time: 1.3612 secs
# Epoch: 018, Train Loss: 0.0724, Train MAPE: 0.1588, Train RMSE: 0.0872, Validation Loss: 0.1779, Validation MAPE: 0.4341, Validation RMSE: 0.2096, Training Time: 77.2683/epoch
# Epoch: 018, Inference Time: 1.2253 secs
# Epoch: 018, Train Loss: 0.0728, Train MAPE: 0.1533, Train RMSE: 0.0868, Validation Loss: 0.1732, Validation MAPE: 0.4228, Validation RMSE: 0.2043, Training Time: 103.2333/epoch
# Epoch: 018, Inference Time: 1.2213 secs
# Epoch: 018, Train Loss: 0.0747, Train MAPE: 0.1535, Train RMSE: 0.0890, Validation Loss: 0.1838, Validation MAPE: 0.4487, Validation RMSE: 0.2154, Training Time: 129.4802/epoch
# Epoch: 018, Inference Time: 1.2493 secs
# Epoch: 018, Train Loss: 0.0721, Train MAPE: 0.1461, Train RMSE: 0.0859, Validation Loss: 0.2020, Validation MAPE: 0.4931, Validation RMSE: 0.2347, Training Time: 154.7496/epoch
# Epoch: 018, Inference Time: 1.3892 secs
# Epoch: 018, Train Loss: 0.0706, Train MAPE: 0.1432, Train RMSE: 0.0840, Validation Loss: 0.2095, Validation MAPE: 0.5114, Validation RMSE: 0.2427, Training Time: 180.6106/epoch
# Epoch: 018, Inference Time: 1.2463 secs
# Epoch: 018, Train Loss: 0.0728, Train MAPE: 0.1488, Train RMSE: 0.0867, Validation Loss: 0.2097, Validation MAPE: 0.5120, Validation RMSE: 0.2425, Training Time: 206.4527/epoch
# Epoch: 018, Inference Time: 1.2513 secs
# Epoch: 018, Train Loss: 0.0742, Train MAPE: 0.1544, Train RMSE: 0.0881, Validation Loss: 0.2050, Validation MAPE: 0.5003, Validation RMSE: 0.2377, Training Time: 232.3987/epoch
# Iter: 000, Train Loss: 0.0800, Train MAE: 0.0800, Train MAPE: 0.1826, Train RMSE: 0.0950
# Epoch: 019, Inference Time: 1.1933 secs
# Epoch: 019, Train Loss: 0.0800, Train MAPE: 0.1826, Train RMSE: 0.0950, Validation Loss: 0.1953, Validation MAPE: 0.4767, Validation RMSE: 0.2275, Training Time: 24.8656/epoch
# Epoch: 019, Inference Time: 1.3562 secs
# Epoch: 019, Train Loss: 0.0777, Train MAPE: 0.1644, Train RMSE: 0.0920, Validation Loss: 0.1860, Validation MAPE: 0.4540, Validation RMSE: 0.2178, Training Time: 50.9156/epoch
# Epoch: 019, Inference Time: 1.2183 secs
# Epoch: 019, Train Loss: 0.0716, Train MAPE: 0.1476, Train RMSE: 0.0849, Validation Loss: 0.1790, Validation MAPE: 0.4370, Validation RMSE: 0.2101, Training Time: 77.5932/epoch
# Epoch: 019, Inference Time: 1.3062 secs
# Epoch: 019, Train Loss: 0.0688, Train MAPE: 0.1382, Train RMSE: 0.0817, Validation Loss: 0.1833, Validation MAPE: 0.4474, Validation RMSE: 0.2147, Training Time: 102.9145/epoch
# Epoch: 019, Inference Time: 1.2243 secs
# Epoch: 019, Train Loss: 0.0687, Train MAPE: 0.1369, Train RMSE: 0.0812, Validation Loss: 0.1973, Validation MAPE: 0.4816, Validation RMSE: 0.2302, Training Time: 128.6357/epoch
# Epoch: 019, Inference Time: 1.1893 secs
# Epoch: 019, Train Loss: 0.0668, Train MAPE: 0.1325, Train RMSE: 0.0790, Validation Loss: 0.2083, Validation MAPE: 0.5083, Validation RMSE: 0.2425, Training Time: 154.1609/epoch
# Epoch: 019, Inference Time: 1.2213 secs
# Epoch: 019, Train Loss: 0.0734, Train MAPE: 0.1543, Train RMSE: 0.0863, Validation Loss: 0.2176, Validation MAPE: 0.5310, Validation RMSE: 0.2532, Training Time: 180.6566/epoch
# Epoch: 019, Inference Time: 1.2763 secs
# Epoch: 019, Train Loss: 0.0738, Train MAPE: 0.1541, Train RMSE: 0.0871, Validation Loss: 0.2086, Validation MAPE: 0.5090, Validation RMSE: 0.2439, Training Time: 207.0344/epoch
# Epoch: 019, Inference Time: 1.3322 secs
# Epoch: 019, Train Loss: 0.0733, Train MAPE: 0.1525, Train RMSE: 0.0868, Validation Loss: 0.1897, Validation MAPE: 0.4628, Validation RMSE: 0.2237, Training Time: 233.1623/epoch
# Iter: 000, Train Loss: 0.0662, Train MAE: 0.0662, Train MAPE: 0.1331, Train RMSE: 0.0796
# Epoch: 020, Inference Time: 1.3172 secs
# Epoch: 020, Train Loss: 0.0662, Train MAPE: 0.1331, Train RMSE: 0.0796, Validation Loss: 0.1777, Validation MAPE: 0.4334, Validation RMSE: 0.2102, Training Time: 24.9836/epoch
# Epoch: 020, Inference Time: 1.4512 secs
# Epoch: 020, Train Loss: 0.0685, Train MAPE: 0.1309, Train RMSE: 0.0812, Validation Loss: 0.1754, Validation MAPE: 0.4278, Validation RMSE: 0.2075, Training Time: 51.2574/epoch
# Epoch: 020, Inference Time: 1.3162 secs
# Epoch: 020, Train Loss: 0.0766, Train MAPE: 0.1504, Train RMSE: 0.0913, Validation Loss: 0.1840, Validation MAPE: 0.4490, Validation RMSE: 0.2172, Training Time: 78.2338/epoch
# Epoch: 020, Inference Time: 1.3362 secs
# Epoch: 020, Train Loss: 0.0766, Train MAPE: 0.1506, Train RMSE: 0.0910, Validation Loss: 0.2063, Validation MAPE: 0.5033, Validation RMSE: 0.2413, Training Time: 103.8500/epoch
# Epoch: 020, Inference Time: 1.4352 secs
# Epoch: 020, Train Loss: 0.0749, Train MAPE: 0.1475, Train RMSE: 0.0893, Validation Loss: 0.2163, Validation MAPE: 0.5278, Validation RMSE: 0.2518, Training Time: 135.9181/epoch
# Epoch: 020, Inference Time: 1.2493 secs
# Epoch: 020, Train Loss: 0.0761, Train MAPE: 0.1586, Train RMSE: 0.0905, Validation Loss: 0.2153, Validation MAPE: 0.5253, Validation RMSE: 0.2510, Training Time: 170.2498/epoch
# Epoch: 020, Inference Time: 1.2613 secs
# Epoch: 020, Train Loss: 0.0771, Train MAPE: 0.1589, Train RMSE: 0.0913, Validation Loss: 0.1959, Validation MAPE: 0.4780, Validation RMSE: 0.2297, Training Time: 200.2545/epoch
# Epoch: 020, Inference Time: 1.5151 secs
# Epoch: 020, Train Loss: 0.0752, Train MAPE: 0.1546, Train RMSE: 0.0890, Validation Loss: 0.1791, Validation MAPE: 0.4370, Validation RMSE: 0.2104, Training Time: 228.4123/epoch
# Epoch: 020, Inference Time: 1.3042 secs
# Epoch: 020, Train Loss: 0.0749, Train MAPE: 0.1530, Train RMSE: 0.0884, Validation Loss: 0.1717, Validation MAPE: 0.4190, Validation RMSE: 0.2020, Training Time: 257.0048/epoch

# %%
validpredlist = []
for eachgroup in his_valid_pred[len(his_valid_pred)-1]:
    for eachteam in eachgroup:
        for i in range(0,96):
            validpredlist.append(eachteam[0][i].item())           
validpred = np.array(validpredlist)
validpred = validpred[0:384]

## load ytest
yvaliddf = pd.read_excel("ytest.xlsx")
yori_valid = np.array(yvaliddf['Yori'])
ynorm_valid = np.array(yvaliddf['Ystar'])

aa_valid = yori_valid
bb_valid = (np.max(yori_valid) - np.min(yori_valid))*validpred + np.min(yori_valid)
cc_valid = ynorm_valid

# test R2
expvar1 = np.sum((cc_valid - validpred)**2)
expvar2 = np.sum((cc_valid - np.mean(cc_valid))**2)
testR2 = 1 - expvar1/expvar2

# test rmse
testrmse = math.sqrt(np.mean(np.square(aa_valid - bb_valid)))

# %%
testR2
# Out:
# 0.4991668282947148

# %%
testrmse
# Out:
# 4.809622700556433

# %%
validpred
# Out:
# array([0.52520025, 0.39454666, 0.65128613, 0.49401063, 0.71062827,
#        0.54531711, 0.75248855, 0.65212256, 0.70208585, 0.69176352,
#        0.54878247, 0.40754393, 0.44095001, 0.63650531, 0.4913204 ,
#        0.54666656, 0.74093866, 0.72249359, 0.67972797, 0.65552825,
#        0.46946982, 0.48427778, 0.3931227 , 0.61417764, 0.36549133,
#        0.61873633, 0.47186679, 0.5858776 , 0.60645503, 0.35943773,
#        0.58717757, 0.64873201, 0.69985336, 0.63112909, 0.38225392,
#        0.46552929, 0.32019714, 0.5650534 , 0.66399163, 0.64281619,
#        0.58094585, 0.67032564, 0.72626179, 0.65545285, 0.42567363,
#        0.4496246 , 0.68050218, 0.64920729, 0.70902854, 0.69917625,
#        0.57304907, 0.47259891, 0.33457237, 0.67540741, 0.56649423,
#        0.35211918, 0.65563786, 0.55155027, 0.73689681, 0.64500648,
#        0.66157746, 0.42346326, 0.56338835, 0.72625637, 0.68450791,
#        0.66263896, 0.68237787, 0.31993526, 0.73498154, 0.53689075,
#        0.43180725, 0.6923719 , 0.39814824, 0.39201069, 0.68440497,
#        0.42866257, 0.74048412, 0.5421344 , 0.62428039, 0.53761405,
#        0.48466334, 0.78844416, 0.6878565 , 0.7439425 , 0.39368963,
#        0.64109534, 0.51048255, 0.72693306, 0.37814304, 0.38491845,
#        0.43647033, 0.66483408, 0.59041661, 0.34048605, 0.58037549,
#        0.74079287, 0.52905464, 0.37290603, 0.65558195, 0.48543996,
#        0.69857818, 0.53355056, 0.74511051, 0.64257878, 0.69737738,
#        0.68328887, 0.55471259, 0.41452697, 0.43636736, 0.6369316 ,
#        0.48899531, 0.53470391, 0.73190045, 0.71309483, 0.67272466,
#        0.64544934, 0.46470428, 0.4802025 , 0.39116406, 0.61692476,
#        0.36154622, 0.62072921, 0.47460032, 0.57296491, 0.60852939,
#        0.35398623, 0.58191204, 0.62442791, 0.69759208, 0.62328047,
#        0.37660876, 0.46741486, 0.3112402 , 0.54810876, 0.65233374,
#        0.65224427, 0.58683783, 0.64869094, 0.72158003, 0.65329379,
#        0.42322263, 0.44432619, 0.67441034, 0.64391148, 0.70646596,
#        0.68947023, 0.57252675, 0.46194163, 0.32632783, 0.67849034,
#        0.55394471, 0.35034493, 0.64709055, 0.54347664, 0.73305058,
#        0.64063048, 0.65645349, 0.41771019, 0.55062193, 0.70899409,
#        0.67755425, 0.65554959, 0.67504805, 0.31706694, 0.73094302,
#        0.52621305, 0.42086089, 0.67778331, 0.39666241, 0.38224095,
#        0.67172956, 0.42264473, 0.73328912, 0.53556097, 0.62057096,
#        0.52594101, 0.48709691, 0.77661496, 0.68448174, 0.73604852,
#        0.39441353, 0.62701786, 0.50825685, 0.73616636, 0.37488261,
#        0.37673837, 0.4374662 , 0.65808076, 0.57851249, 0.33412105,
#        0.57451165, 0.73551697, 0.52961886, 0.38419887, 0.64523047,
#        0.49020794, 0.69337839, 0.54265881, 0.7714107 , 0.65329897,
#        0.69495511, 0.6820308 , 0.55445319, 0.41626117, 0.43829736,
#        0.63338226, 0.49477208, 0.54865766, 0.74083197, 0.71246374,
#        0.6974023 , 0.65879941, 0.47640929, 0.48401859, 0.39835507,
#        0.61451763, 0.35990849, 0.62359089, 0.48115203, 0.58792639,
#        0.60901386, 0.35980925, 0.5906958 , 0.63767749, 0.70204329,
#        0.61246783, 0.38416818, 0.46443149, 0.32475832, 0.56255013,
#        0.67235237, 0.65222949, 0.57692289, 0.65346289, 0.71476918,
#        0.65246534, 0.43144122, 0.45152053, 0.68103623, 0.65803629,
#        0.70757788, 0.69965583, 0.57404554, 0.46604851, 0.32712367,
#        0.67897493, 0.55883271, 0.33982781, 0.65337342, 0.54459149,
#        0.73563129, 0.64391369, 0.66573942, 0.42187962, 0.55981493,
#        0.71700901, 0.68296313, 0.66835999, 0.68369967, 0.32034081,
#        0.73310333, 0.53774369, 0.42497501, 0.68296117, 0.40274227,
#        0.3895393 , 0.6745066 , 0.4231838 , 0.72413307, 0.54503822,
#        0.61575383, 0.51435351, 0.49404189, 0.78523552, 0.68421876,
#        0.73751652, 0.39884374, 0.63715929, 0.51238453, 0.73627007,
#        0.37771016, 0.37843108, 0.43161327, 0.65823722, 0.5809356 ,
#        0.33750105, 0.57534134, 0.7422291 , 0.53547257, 0.38645506,
#        0.65710145, 0.49228251, 0.69873601, 0.53706336, 0.77235544,
#        0.65240717, 0.70515019, 0.68765414, 0.55410445, 0.42838749,
#        0.44533885, 0.63588744, 0.49278286, 0.5506795 , 0.73714995,
#        0.72132915, 0.69099015, 0.64993715, 0.47259548, 0.49250275,
#        0.39706203, 0.6202631 , 0.36587313, 0.62698144, 0.47208533,
#        0.58670658, 0.60193342, 0.36495069, 0.58945715, 0.63605827,
#        0.70271593, 0.64015782, 0.38612556, 0.4745014 , 0.32127485,
#        0.5581044 , 0.67181718, 0.65613246, 0.58744407, 0.65635616,
#        0.71893269, 0.66270328, 0.42631358, 0.46208212, 0.68097311,
#        0.64513797, 0.70975876, 0.69562703, 0.57552367, 0.47273615,
#        0.32130885, 0.66653055, 0.55901808, 0.35459822, 0.66622633,
#        0.54922456, 0.73947304, 0.64470822, 0.66752416, 0.42611584,
#        0.55755043, 0.71933651, 0.68419862, 0.66459996, 0.68550873,
#        0.32033601, 0.74284649, 0.54275906, 0.42385739, 0.68813163,
#        0.39163092, 0.39298287, 0.67272806, 0.43130782, 0.73717016,
#        0.53885221, 0.62409061, 0.52750677, 0.49964643, 0.77692467,
#        0.68886399, 0.74809444, 0.40611985, 0.63688469, 0.52732325,
#        0.73053569, 0.36507648, 0.38316292, 0.44353777, 0.66403413,
#        0.5874176 , 0.33893785, 0.58218443, 0.73276877])

# %%
storelist = ['Test'] + list(validpred)
storelist = np.array(storelist)
np.savetxt('Test.txt', storelist, fmt="%s", delimiter=',')
